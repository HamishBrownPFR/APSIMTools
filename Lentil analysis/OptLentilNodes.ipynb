# %% [markdown]
# # Optimisation functions

# %%
import datetime as dt
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import subprocess 
import sqlite3
import scipy.optimize 
from skopt import gp_minimize
from skopt.callbacks import CheckpointSaver
from skopt import load
from skopt.plots import plot_convergence
from skopt.space import Real
from skopt.space import Space
from skopt import Optimizer
from skopt.utils import create_result
import matplotlib.gridspec as gridspec
import os
from pathlib import Path

# %matplotlib inline

def calcLoss(fitting_variables, obs_pred):
    """
    Calculate loss using NSE with:
    - Strict validation (fatal on structural issues)
    - Smooth squashing for poor NSE
    - Full resolution for good NSE
    """

    sc_obs = []
    sc_pred = []

    # -------------------------
    # Extract and scale data
    # -------------------------
    for var in fitting_variables:
        obs_col = f"Observed.{var}"
        pred_col = f"Predicted.{var}"

        if obs_col not in obs_pred or pred_col not in obs_pred:
            print(f"⚠️ Skipping variable '{var}' (missing columns)")
            continue
        
        df = obs_pred[[obs_col, pred_col]].dropna()

        if df.empty:
            print(f"No valid data for variable '{var}' after dropping NaNs")
            continue

        # Ensure numeric
        df[obs_col] = pd.to_numeric(df[obs_col], errors="coerce")
        df[pred_col] = pd.to_numeric(df[pred_col], errors="coerce")

        df = df.dropna()

        if df.empty:
            raise RuntimeError(
                f"No valid numeric data for variable '{var}'"
            )

        v_max = df[obs_col].max()
        v_min = df[obs_col].min()

        # -------------------------
        # Scaling safety (should not happen now)
        # -------------------------
        if v_max == v_min:
            raise RuntimeError(
                f"Zero variation in observations for '{var}'. "
                "This indicates a data or simulation issue."
            )

        # Scale to 0–1
        obs_scaled = (df[obs_col] - v_min) / (v_max - v_min)
        pred_scaled = (df[pred_col] - v_min) / (v_max - v_min)

        sc_obs.append(obs_scaled.values)
        sc_pred.append(pred_scaled.values)

    # -------------------------
    # Final concatenation
    # -------------------------
    if not sc_obs:
        raise RuntimeError(
            "No valid observation/prediction data found across all variables."
        )

    sc_obs = np.concatenate(sc_obs)
    sc_pred = np.concatenate(sc_pred)

    # -------------------------
    # NSE calculation
    # -------------------------
    obs_mean = np.mean(sc_obs)
    denominator = np.sum((sc_obs - obs_mean) ** 2)

    if denominator == 0:
        raise RuntimeError(
            "Zero variance in observations (NSE undefined). "
            "Check simulation outputs."
        )

    nse = 1.0 - np.sum((sc_obs - sc_pred) ** 2) / denominator

    # -------------------------
    # LOSS TRANSFORMATION
    # -------------------------
    # Keep full resolution for good fits
    if nse >= 0:
        loss = -nse
    else:
        # Smooth squash for poor fits (no hard cap)
        loss = np.tanh(-nse)

    return loss, len(sc_obs), sc_obs, sc_pred

class ResultsStore:
    def __init__(self):
        self.records = []
        self.iteration = 0

    def addResult(
        self,
        cultivar,
        parameters,
        loss,
        nObs,
        runtime=None,
        obs=None,
        pred=None,
        variable=None,
    ):
        """
        Store results from one APSIM evaluation.

        obs, pred: array-like (NumPy arrays or lists)
        variable: name of fitted variable (optional)
        """
        self.iteration += 1

        record = {
            "iteration": self.iteration,
            "cultivar": cultivar,
            "loss": loss,
            "n_obs": nObs,
            "runtime": runtime,
            "variable": variable,
            **{f"param_{k}": v for k, v in parameters.items()}
        }

        # Store arrays as-is (NumPy arrays are fine)
        record["obs"] = obs
        record["pred"] = pred

        self.records.append(record)

    def to_dataframe(self, drop_arrays=False):
        """
        Convert to DataFrame. Optionally drop obs/pred arrays.
        """
        if drop_arrays:
            return pd.DataFrame([
                {k: v for k, v in r.items() if k not in ("obs", "pred")}
                for r in self.records
            ])
        return pd.DataFrame(self.records)

def runModelGetStats(runSpec, paramSet, fittingVariables):

    apsimx = os.path.join(runSpec["simulationPath"], f"{runSpec['apsimFileName']}.apsimx")
    apply  = os.path.join(runSpec["simulationPath"], f"tempApplyCLI.txt")
    
    db = os.path.join(runSpec["simulationPath"], f"{runSpec['apsimFileName']}.db")
    db_path = Path(db)

    # Ensure clean DB
    if db_path.exists():
        db_path.unlink()

    # Write apply file
    write_cultivar_apply_file(apply_path=Path(apply),apsimx_path=Path(apsimx),cultivar_name=runSpec["cultivarName"],
        parameters=paramSet,playListName="tempChooseCultivar")

    start = dt.datetime.now()

    # -----------------------------
    # RUN APSIM (main run)
    # -----------------------------
    result = subprocess.run(
        [
            APSIM_EXE,
            apsimx,
            "--apply", apply,
            "--playlist", "tempChooseCultivar"
        ],
        stdout=subprocess.PIPE,
        stderr=subprocess.STDOUT,
        text=True,
        timeout=300
    )

    output = result.stdout or ""

    # --- Detect NO MATCH case ---
    if "Playlist was used but no simulations or experiments match the contents of the list" in output:
        print(f"⚠️ No matching simulations for {runSpec['apsimFileName']} (skipping)")

        # cleanup before exit
        remove_cultivar_apply_file(apply_path=Path(apply),apsimx_path=Path(apsimx),
            cultivar_name=runSpec["cultivarName"],playListName="tempChooseCultivar")

        subprocess.run(
            [APSIM_EXE, apsimx, "--apply", apply],
            stdout=subprocess.PIPE,
            stderr=subprocess.STDOUT,
            text=True
        )

        endrun = dt.datetime.now()
        runtime = (endrun - start).seconds

        return pd.DataFrame(), runtime

    # --- Print only meaningful output ---
    if output.strip():
        print(output)

    #-----------------------------
    #CLEANUP (remove temp nodes)
    #-----------------------------
    remove_cultivar_apply_file(
        apply_path=Path(apply),
        apsimx_path=Path(apsimx),
        cultivar_name=runSpec["cultivarName"],
        playListName="tempChooseCultivar"
    )

    result = subprocess.run(
        [
            APSIM_EXE,
            apsimx,
            "--apply", apply
        ],
        stdout=subprocess.PIPE,
        stderr=subprocess.STDOUT,
        text=True
    )

    if result.stdout and result.stdout.strip():
        print(result.stdout)

    endrun = dt.datetime.now()
    runtime = (endrun - start).seconds

    # -----------------------------
    # SAFE DB READ
    # -----------------------------
    if not os.path.exists(db):
        print(f"⚠️ DB not created for {runSpec['apsimFileName']} (skipping)")
        return pd.DataFrame(), runtime

    con = sqlite3.connect(db)

    try:
        tables = pd.read_sql(
            "SELECT name FROM sqlite_master WHERE type='table';",
            con
        )["name"].tolist()
    
        # if runSpec['reportName'] not in tables:
        #     print(f"⚠️ Table {runSpec['reportName']} missing in {runSpec['apsimFileName']} (skipping)")
        #     return pd.DataFrame(), runtime
    
        # obs_pred = pd.read_sql(f"SELECT * FROM {runSpec['reportName']}", con)
    
        dfs = []
    
        for rep in runSpec['reportName']:
        
            if rep not in tables:
                print(f"⚠️ Table {rep} missing in {runSpec['apsimFileName']} (skipping)")
                continue
        
            df = pd.read_sql(f"SELECT * FROM {rep}", con)
        
            df["source_table"] = rep  # optional debug
        
            dfs.append(df)
        
        if not dfs:
            print(f"⚠️ No valid report tables for {runSpec['apsimFileName']}")
            return pd.DataFrame(), runtime
        
        # align columns
        all_cols = set().union(*[df.columns for df in dfs])
        dfs = [df.reindex(columns=all_cols) for df in dfs]
        
        # ✅ STACK rows
        obs_pred = pd.concat(dfs, ignore_index=True, sort=False)

    finally:
        con.close()

    return obs_pred, runtime

def runModelItter(runSpecs, paramSet, fittingVariables, resultsStore=None, printResult=False):
    """
    Run one parameter set across all APSIM files listed in runSpecs and merge results.
    """

    allObsPred = []
    totalRuntime = 0
    itter = 0

    for runSpec in runSpecs:
        obsPred, runtime = runModelGetStats(
            runSpec=runSpec,
            paramSet=paramSet,
            fittingVariables=fittingVariables
        )

        if not obsPred.empty:
            allObsPred.append(obsPred)

        totalRuntime += runtime

        
    if len(allObsPred) == 0:
        print("❌ No valid simulations produced data")
        return 2.0

    obsPredAll = pd.concat(allObsPred, ignore_index=True)

    # Compute loss and scaled values
    loss, nObs, scObs, scPred = calcLoss(fittingVariables, obsPredAll)

    # Optional: store results
    if resultsStore is not None:
        resultsStore.addResult(
            cultivar=runSpecs[0]["cultivarName"],
            parameters=paramSet,
            loss=loss,
            nObs=nObs,
            runtime=totalRuntime,
            obs=scObs,
            pred=scPred
        )
        
        itter = resultsStore.iteration

    if printResult:
        print(
            f"[{itter:03d}] | "
            f"{list(paramSet.values())} run completed | "
            f"{nObs} obs in {totalRuntime} seconds. | "
            f"NSE = {-loss:.3f}"
        )

    return loss

# ------------------------------------------------------------
# Stagnation detection helpers
# ------------------------------------------------------------

def stagnation_detected(res, window=5, eps=None):
    """
    Detect whether the optimiser has stopped moving in parameter space.
    """
    if len(res.x_iters) < window + 1:
        return False

    recent_moves = np.linalg.norm(
        np.diff(np.array(res.x_iters[-window:]), axis=0),
        axis=1
    )

    return np.max(recent_moves) < eps


def loss_stagnated(res, window=10, tol=0.02):
    """
    Detect whether loss improvement has stalled.
    """
    if len(res.func_vals) < window:
        return False

    y_hist = np.array(res.func_vals)

    best = np.minimum.accumulate(y_hist)
    recent = best[-window:]

    return (recent[0] - recent[-1]) < tol

def format_param(val, p):
    step = p.get("step", None)

    if step is None:
        return f"{val:.3f}"

    # determine decimals from step size
    decimals = max(0, int(-np.log10(step))) if step < 1 else 0

    if decimals == 0:
        return f"{int(round(val))}"
    else:
        return f"{val:.{decimals}f}"

def quantise(x, param_config):
    q = []
    for val, p in zip(x, param_config):
        step = p.get("step", None)
        if step is not None:
            val = round(val / step) * step
        q.append(val)
    return q

import numpy as np

def format_value(val, step):
    """
    Quantise and format a parameter value consistently.
    """

    if step is None:
        return str(val)

    # quantise
    val = round(val / step) * step

    # determine decimals from step
    if step >= 1:
        return str(int(round(val)))
    else:
        decimals = int(round(-np.log10(step)))
        return f"{val:.{decimals}f}"


def fit_cultivar(
    CultivarToFit,
    ObsPredTableName,
    param_config,
    fitting_variables,
    random_sample_size=29,
    stage_size=10,
    max_stages=5,
    shrink_factor=0.05,
    local_steps=10
):

    # -------------------------
    # Build structures
    # -------------------------
    paramNames = [p["name"] for p in param_config]

    space_dims = [
        Real(p["bounds"][0], p["bounds"][1], name=p["short_name"])
        for p in param_config
    ]

    expert_guesses = [[p["initial"] for p in param_config]]

    space = Space(space_dims)

    opt = Optimizer(
        dimensions=space_dims,
        base_estimator="GP",
        acq_func="EI",
        random_state=42
    )

    STORE = ResultsStore()

    RUNSPECS = create_runSpecs_for_cultivar(
        CultivarToFit,
        ObsPredTableName
    )

    # -------------------------
    # Objective with quantisation
    # -------------------------
    def objective(x):
        xq = quantise(x, param_config)
    
        param_dict = dict(zip(paramNames, xq))
    
        loss = runModelItter(
            RUNSPECS,
            param_dict,
            fitting_variables,
            resultsStore=STORE,
            printResult=False
        )
    
        itter = STORE.iteration
        param_str = ", ".join(
            f"{p['short_name']}={format_param(v, p)}"
            for p, v in zip(param_config, xq)
        )
        
        runtime = STORE.records[-1]["runtime"]
        nobs = STORE.records[-1]["n_obs"]
        
        print(
            f"[{itter:03d}] {param_str} | "
            f"Loss = {loss:.4f} | "
            f"n = {nobs} | "
            f"{runtime:.1f}s"
        )

        return loss

    # -------------------------
    # Initial design
    # -------------------------
    print(f"\n=== Initial design: {CultivarToFit} ===")

    for x in expert_guesses:
        opt.tell(x, objective(x))

    for x in space.rvs(random_sample_size, random_state=42):
        opt.tell(x, objective(x))

    # -------------------------
    # GP optimisation
    # -------------------------
    param_ranges = np.array([d.high - d.low for d in space_dims])
    eps = 0.01 * np.linalg.norm(param_ranges)

    for stage in range(max_stages):
        print(f"\n=== Stage {stage+1} ===")

        for _ in range(stage_size):
            x = opt.ask()
            y = objective(x)
            opt.tell(x, y)

        x_hist = opt.Xi
        y_hist = np.array(opt.yi)

        if stagnation_detected(
            type("Res", (), {"x_iters": x_hist}),
            window=5,
            eps=eps
        ):
            print("Stopping: parameter stagnation")
            break

        if loss_stagnated(
            type("Res", (), {"func_vals": y_hist}),
            window=10,
            tol=1e-3
        ):
            print("Stopping: loss stagnation")
            break

    # -------------------------
    # Best global solution
    # -------------------------
    best_idx = int(np.argmin(opt.yi))
    best_x = opt.Xi[best_idx]
    best_y = opt.yi[best_idx]

    print("\n=== Global optimum ===")
    print(f"Loss: {best_y:.4f}")

    # -------------------------
    # LOCAL REFINEMENT
    # -------------------------
    print("\n=== Local refinement ===")

    local_config = []

    for val, p in zip(best_x, param_config):

        low, high = p["bounds"]
        base_range = (high + low)/2

        delta = max(
            abs(val) * shrink_factor,
            0.05 * base_range
        )

        new_low = max(low, val - delta)
        new_high = min(high, val + delta)

        local_p = p.copy()
        local_p["bounds"] = (new_low, new_high)
        local_p["initial"] = val

        local_config.append(local_p)

    # build local GP
    local_space = [
        Real(p["bounds"][0], p["bounds"][1], name=p["short_name"])
        for p in local_config
    ]

    local_opt = Optimizer(
        dimensions=local_space,
        base_estimator="GP",
        acq_func="EI",
        random_state=42
    )

    # seed
    local_opt.tell(best_x, objective(best_x))

    # run local GP
    for i in range(local_steps):
        x = local_opt.ask()
        y = objective(x)
        local_opt.tell(x, y)

    best_local_idx = int(np.argmin(local_opt.yi))
    best_x = local_opt.Xi[best_local_idx]
    best_y = local_opt.yi[best_local_idx]

    print("\n=== Final result ===")
    print(f"Loss: {best_y:.4f}")

    for p, val in zip(param_config, quantise(best_x, param_config)):
        print(f"{p['short_name']}: {val}")

    return quantise(best_x, param_config), best_y, STORE, opt

# %%
Colors = {1:'#000000',
2:'#E69F00',
3:'#56B4E9',
4:'#009E73',
5:'#F0E442',
6:'#0072B2',
7:'#D55E00',
8:'#CC79A7',
9:'#1F77B4',
10:'#AEC7E8',
11:'#FF7F0E',
12:'#FFBB78',
13:'#2CA02C',
14:'#98DF8A',
15:'#D62728',
16:'#FF9896',
17:'#9467BD',
18:'#C5B0D5',
19:'#8C564B',
20:'#C49C94',
21:'#E377C2',
22:'#F7B6D2',
23:'#7F7F7F',
24:'#C7C7C7',
25:'#BCBD22',
26:'#DBDB8D',
27:'#17BECF',
28:'#9EDAE5'}

# %% [markdown]
# # Test with single param set on single file

# %% [markdown]
# ## functions to prepare .apsimx files
# Inject and remove cultivar replacement and playlist to select that cultivar

# %%
def write_cultivar_apply_file(apply_path: Path, apsimx_path: Path, cultivar_name: str, parameters: dict, playListName: str):
    """
    Write an APSIM apply file to select a cultivar and override its parameters.

    parameters: dict mapping APSIM variable paths to values, e.g.
        {
            "[Phenology].JuvenileBase.FixedValue": 30,
            "[Phenology].VernSensitivity.FixedValue": 0.22,
        }
    """

    lines = []

    # Load base apsimx
    lines.append(f"load {apsimx_path}")

    # Select cultivar via playlist
    lines.append(f"add new Playlist to [Simulations] name {playListName}")
    lines.append(f"[{playListName}].Text=*{cultivar_name}*")

    # Build command list
    lines.append(f"add new Cultivar to [Replacements] name {cultivar_name}")
    lines.append(f"[Replacements].{cultivar_name}.Command = ")
    
    for key, value in parameters.items():
        lines.append(f' {key} = {value},')

    # Remove trailing comma on last entry
    lines[-1] = lines[-1].rstrip(",")
    
    # Save and run
    lines.append(f"save {apsimx_path}")
    lines.append("run")
    
    apply_path.write_text("\n".join(lines))
    
def remove_cultivar_apply_file(apply_path: Path, apsimx_path: Path, cultivar_name: str, playListName: str):
    """
    Write an APSIM apply file to remove the play list and cultivar added to replacements so clean for next run.

    """
    lines = []

    # Load base apsimx
    lines.append(f"load {apsimx_path}")

    # Delete temporary components from fitting
    lines.append(f"delete [Simulations].{playListName}")
    lines.append(f"delete [Replacements].{cultivar_name}")

    # Save
    lines.append(f"save {apsimx_path}")
    
    apply_path.write_text("\n".join(lines))

# %% [markdown]
# ## run single file test

# %%
FITTING_VARIABLES = ['Lentil.Leaf.NodeNumber',
                     'Lentil.Phenology.MaturityDAS']

APSIM_EXE = r"C:\GitHubRepos\ApsimX\bin\Debug\net8.0\Models.exe"

cultivar_params = {
                    '[Phenology].MinFloralNodes.FixedValue':12,
                     '[Phenology].PpFloralNodes.FixedValue':0,
                     '[Leaf].BasePhyllochron.FixedValue':52,
                     '[Leaf].Phyllochron.EarlyVegetative.Phyllochron.EarlyLeafResponse.Decrease.Size.FixedValue':0.3
                  }

runSpec = {
             "cultivarName":"Bolt",
             #"cultivarName":"HallmarkXT",
             "simulationPath":r"C:\GitHubRepos\ApsimX\Prototypes\Lentil\NaPA",
             #"simulationPath":r"C:\GitHubRepos\ApsimX\Prototypes\Lentil",
             "apsimFileName":"2022_NSW_WaggaWagga_Lentil_Detailed",
             "reportName":["DailyObsPred","HarvestObsPred"]
           }

testStore = ResultsStore()
runSpecs = []
runSpecs.append(runSpec)
runModelItter(runSpecs, cultivar_params, FITTING_VARIABLES, resultsStore=testStore, printResult=True)
df = testStore.to_dataframe()
# Out:
# No valid data for variable 'Lentil.Leaf.NodeNumber' after dropping NaNs
# [001] | [12, 0, 52, 0.3] run completed | 2 obs in 6 seconds. | NSE = -1.000

# %% [markdown]
# # Test with single cultivar over multiple files

# %% [markdown]
# ## Index of which cultivars are in which files

# %%
CULTIVAR_FILE_DICT = {
 'Ace': ['Lentil.apsimx'],
 'Blitz': ['Lentil.apsimx'],
 'Bolt': ['2022_NSW_WaggaWagga_Lentil_Detailed.apsimx',
  '2022_SA_Riverton_Lentil_Detailed.apsimx',
  '2023_SA_Pinery_Lentil_Detailed.apsimx',
  '2023_Vic_Dooen_Lentil_Detailed.apsimx',
  'Lentil.apsimx'],
 'Digger': ['Lentil.apsimx'],
 'Greenfield': ['Lentil.apsimx'],
 'HallmarkXT': ['2022_NSW_WaggaWagga_Lentil_Detailed.apsimx',
  '2022_SA_Riverton_Lentil_Detailed.apsimx',
  '2023_SA_Pinery_Lentil_Detailed.apsimx',
  '2023_Vic_Dooen_Lentil_Detailed.apsimx',
  'Lentil.apsimx'],
 'Jumbo2': ['2022_NSW_WaggaWagga_Lentil_Detailed.apsimx',
  '2022_SA_Riverton_Lentil_Detailed.apsimx',
  '2022_Vic_Kalkee_Lentil_Detailed.apsimx',
  '2023_SA_Pinery_Lentil_Detailed.apsimx',
  '2023_Vic_Dooen_Lentil_Detailed.apsimx',
  'Lentil.apsimx'],
 'KelpieXT': ['2022_NSW_WaggaWagga_Lentil_Detailed.apsimx',
  '2022_SA_Riverton_Lentil_Detailed.apsimx',
  '2022_Vic_Kalkee_Lentil_Detailed.apsimx',
  '2023_SA_Pinery_Lentil_Detailed.apsimx',
  '2023_Vic_Dooen_Lentil_Detailed.apsimx'],
 'Nugget': ['Lentil.apsimx']
}

# %% [markdown]
# ## Functions to create data structures for running cultivar

# %%
def create_filesToRun_for_cultivar(cultivar_name):
    """
    Create filesToRun list for a given cultivar using mapping dictionary.
    """

    BASE_MAIN = r"C:\GitHubRepos\ApsimX\Prototypes\Lentil"
    BASE_NAPA = r"C:\GitHubRepos\ApsimX\Prototypes\Lentil\NaPA"
    BASE_FAHMA = r"C:\GitHubRepos\ApsimX\Prototypes\Lentil\FAHMA"

    filesToRun = []

    file_list = CULTIVAR_FILE_DICT.get(cultivar_name, [])

    for fname in file_list:

        if fname == "Lentil.apsimx":
            filesToRun.append({
                "dir": BASE_MAIN,
                "name": "Lentil"
            })
        elif fname == "FAHMA_Lentil.apsimx":
            filesToRun.append({
                "dir": BASE_FAHMA,
                "name": "FAHMA_Lentil"
            })
        else:
            filesToRun.append({
                "dir": BASE_NAPA,
                "name": fname.replace(".apsimx", "")
            })

    return filesToRun

def create_runSpecs_for_cultivar(cultivarName, reportName):
    runSpecs = []
    
    baseRunSpec = {
                 "cultivarName":cultivarName,
                 "simulationPath":None,
                 "apsimFileName":None,
                 "reportName":reportName
               }

    filesToRun = create_filesToRun_for_cultivar(cultivarName)

    for fTR in filesToRun:
        fileRunSpec = baseRunSpec.copy()
        fileRunSpec["apsimFileName"] = fTR['name']
        fileRunSpec["simulationPath"] = fTR['dir']
        runSpecs.append(fileRunSpec)
    
    return runSpecs

# %% [markdown]
# ## Run multiple files for selected cultivar with specified parameter set

# %%
cultivar_params = {
                    '[Phenology].MinFloralNodes.FixedValue':20,
                     '[Phenology].PpFloralNodes.FixedValue':20,
                     '[Leaf].BasePhyllochron.FixedValue':50,
                     '[Leaf].Phyllochron.EarlyVegetative.Phyllochron.EarlyLeafResponse.Decrease.Size.FixedValue':0.8
                  }

runSpecs = create_runSpecs_for_cultivar("HallmarkXT", ["DailyObsPred","HarvestObsPred"])

storeMulti = ResultsStore()

runModelItter(runSpecs, cultivar_params, FITTING_VARIABLES, resultsStore=storeMulti, printResult=True)
df = testStore.to_dataframe()
# Out:
# [001] | [20, 20, 50, 0.8] run completed | 118 obs in 35 seconds. | NSE = -0.868

# %% [markdown]
# # Run optimisation to find best fit parameters for specific cultivar

# %% [markdown]
# ## Run optimisation

# %%
Fitting_Variables = ['Lentil.Leaf.NodeNumber']

# ------------------------------------------------------------
# Parameter definitions
# ------------------------------------------------------------

param_config = [
    {
        "name": "[Phenology].MinFloralNodes.FixedValue",
        "short_name": "MinNod",
        "bounds": (0, 40),
        "step": 1,
        "initial": 15
    },
    {
        "name": "[Phenology].PpFloralNodes.FixedValue",
        "short_name": "MaxNod",
        "bounds": (0, 60),
        "step": 1,
        "initial": 30
    },
    {
        "name": "[Leaf].BasePhyllochron.FixedValue",
        "short_name": "BasPhy",
        "bounds": (10, 100),
        "step": 1,
        "initial": 30
    },
    {
        "name": '[Leaf].Phyllochron.EarlyVegetative.Phyllochron.EarlyLeafResponse.Decrease.Size.FixedValue',
        "short_name": "ElyPhy",
        "bounds": (0, .75),
        "step": 0.05,
        "initial": 0.3
    }
    
]

best_x, best_y, STORE, opt = fit_cultivar(
                                            CultivarToFit = 'Digger',
                                            ObsPredTableName = ["DailyObsPred","HarvestObsPred"],
                                            fitting_variables=Fitting_Variables,
                                            param_config=param_config,
                                            random_sample_size=15,
                                            stage_size=10,
                                            max_stages=5,
                                            shrink_factor=0.1,
                                            local_steps=10
                                        )
# Out:
# === Initial design: Digger ===
# [001] MinNod=15, MaxNod=30, BasPhy=30, ElyPhy=0.3 | Loss = 0.9927 | n = 24 | 14.0s
# [002] MinNod=15, MaxNod=11, BasPhy=65, ElyPhy=0.5 | Loss = -0.6613 | n = 24 | 14.0s
# [003] MinNod=38, MaxNod=18, BasPhy=25, ElyPhy=0.2 | Loss = 1.0000 | n = 24 | 15.0s
# [004] MinNod=29, MaxNod=31, BasPhy=16, ElyPhy=0.4 | Loss = 1.0000 | n = 24 | 14.0s
# [005] MinNod=24, MaxNod=26, BasPhy=95, ElyPhy=0.4 | Loss = 0.5138 | n = 24 | 14.0s
# [006] MinNod=6, MaxNod=17, BasPhy=97, ElyPhy=0.2 | Loss = 0.5584 | n = 24 | 14.0s
# [007] MinNod=6, MaxNod=37, BasPhy=83, ElyPhy=0.8 | Loss = 0.1265 | n = 24 | 14.0s
# [008] MinNod=2, MaxNod=8, BasPhy=37, ElyPhy=0.6 | Loss = 0.9983 | n = 24 | 14.0s
# [009] MinNod=35, MaxNod=18, BasPhy=19, ElyPhy=0.7 | Loss = 1.0000 | n = 24 | 14.0s
# [010] MinNod=24, MaxNod=22, BasPhy=72, ElyPhy=0.7 | Loss = -0.4026 | n = 24 | 12.0s
# [011] MinNod=28, MaxNod=27, BasPhy=50, ElyPhy=0.5 | Loss = -0.8610 | n = 24 | 13.0s
# [012] MinNod=1, MaxNod=47, BasPhy=21, ElyPhy=0.7 | Loss = 1.0000 | n = 24 | 14.0s
# [013] MinNod=39, MaxNod=12, BasPhy=55, ElyPhy=0.1 | Loss = -0.8100 | n = 24 | 14.0s
# [014] MinNod=33, MaxNod=31, BasPhy=13, ElyPhy=0.2 | Loss = 1.0000 | n = 24 | 14.0s
# [015] MinNod=8, MaxNod=36, BasPhy=92, ElyPhy=0.1 | Loss = 0.4405 | n = 24 | 14.0s
# [016] MinNod=7, MaxNod=3, BasPhy=33, ElyPhy=0.2 | Loss = 0.5472 | n = 24 | 14.0s
#
# === Stage 1 ===
# [017] MinNod=40, MaxNod=60, BasPhy=57, ElyPhy=0.8 | Loss = -0.6456 | n = 24 | 14.0s
# [018] MinNod=0, MaxNod=0, BasPhy=56, ElyPhy=0.0 | Loss = -0.5754 | n = 22 | 13.0s
# [019] MinNod=40, MaxNod=35, BasPhy=53, ElyPhy=0.3 | Loss = -0.9073 | n = 24 | 13.0s
# [020] MinNod=40, MaxNod=60, BasPhy=51, ElyPhy=0.8 | Loss = 0.3625 | n = 24 | 13.0s
# [021] MinNod=16, MaxNod=41, BasPhy=60, ElyPhy=0.7 | Loss = -0.8867 | n = 24 | 13.0s
# [022] MinNod=9, MaxNod=26, BasPhy=53, ElyPhy=0.4 | Loss = -0.9160 | n = 24 | 13.0s
# [023] MinNod=40, MaxNod=33, BasPhy=57, ElyPhy=0.1 | Loss = -0.7570 | n = 24 | 14.0s
# [024] MinNod=29, MaxNod=59, BasPhy=63, ElyPhy=0.5 | Loss = -0.7400 | n = 24 | 13.0s
# [025] MinNod=40, MaxNod=54, BasPhy=49, ElyPhy=0.3 | Loss = -0.9042 | n = 24 | 13.0s
# [026] MinNod=40, MaxNod=10, BasPhy=51, ElyPhy=0.4 | Loss = -0.9061 | n = 24 | 13.0s
#
# === Stage 2 ===
# [027] MinNod=40, MaxNod=60, BasPhy=58, ElyPhy=0.2 | Loss = -0.7735 | n = 24 | 13.0s
# [028] MinNod=40, MaxNod=0, BasPhy=58, ElyPhy=0.6 | Loss = -0.8977 | n = 24 | 13.0s
# [029] MinNod=40, MaxNod=60, BasPhy=46, ElyPhy=0.0 | Loss = -0.9025 | n = 24 | 13.0s
# [030] MinNod=40, MaxNod=60, BasPhy=48, ElyPhy=0.1 | Loss = -0.9118 | n = 24 | 13.0s
# [031] MinNod=40, MaxNod=0, BasPhy=63, ElyPhy=0.8 | Loss = -0.8736 | n = 24 | 13.0s
# [032] MinNod=40, MaxNod=55, BasPhy=71, ElyPhy=0.0 | Loss = -0.2643 | n = 24 | 13.0s
# [033] MinNod=40, MaxNod=60, BasPhy=55, ElyPhy=0.5 | Loss = -0.9114 | n = 24 | 13.0s
# [034] MinNod=40, MaxNod=60, BasPhy=49, ElyPhy=0.0 | Loss = -0.9014 | n = 24 | 13.0s
# [035] MinNod=40, MaxNod=60, BasPhy=61, ElyPhy=0.7 | Loss = -0.8808 | n = 24 | 13.0s
# [036] MinNod=0, MaxNod=60, BasPhy=50, ElyPhy=0.4 | Loss = -0.9101 | n = 24 | 13.0s
# Stopping: loss stagnation
#
# === Global optimum ===
# Loss: -0.9160
#
# === Local refinement ===
# [037] MinNod=9, MaxNod=26, BasPhy=53, ElyPhy=0.4 | Loss = -0.9160 | n = 24 | 13.0s
# [038] MinNod=10, MaxNod=24, BasPhy=56, ElyPhy=0.4 | Loss = -0.8884 | n = 24 | 13.0s
# [039] MinNod=9, MaxNod=24, BasPhy=52, ElyPhy=0.4 | Loss = -0.9136 | n = 24 | 13.0s
# [040] MinNod=8, MaxNod=26, BasPhy=48, ElyPhy=0.4 | Loss = -0.8267 | n = 24 | 13.0s
# [041] MinNod=10, MaxNod=23, BasPhy=58, ElyPhy=0.4 | Loss = -0.8466 | n = 24 | 13.0s
# [042] MinNod=9, MaxNod=23, BasPhy=48, ElyPhy=0.4 | Loss = -0.8267 | n = 24 | 13.0s
# [043] MinNod=9, MaxNod=23, BasPhy=58, ElyPhy=0.4 | Loss = -0.8466 | n = 24 | 13.0s
# [044] MinNod=8, MaxNod=26, BasPhy=52, ElyPhy=0.5 | Loss = -0.9027 | n = 24 | 13.0s
# [045] MinNod=9, MaxNod=27, BasPhy=55, ElyPhy=0.4 | Loss = -0.9029 | n = 24 | 12.0s
# [046] MinNod=8, MaxNod=28, BasPhy=54, ElyPhy=0.4 | Loss = -0.9122 | n = 24 | 13.0s
# [047] MinNod=10, MaxNod=24, BasPhy=54, ElyPhy=0.4 | Loss = -0.9048 | n = 24 | 13.0s
#
# === Final result ===
# Loss: -0.9160
# MinNod: 9
# MaxNod: 26
# BasPhy: 53
# ElyPhy: 0.4

# %% [markdown]
# ## Evolution of loss results

# %%
df = STORE.to_dataframe()

# %%
df.loss.plot()
# Out:
# <Axes: >

# %% [markdown]
# ## Obs vs pred of best fit

# %%
# Find the best iteration (minimum loss)
best_idx = df["loss"].idxmin()
best_row = df.loc[best_idx]
best_iter = best_row["iteration"]

print(f"Best iteration: {best_iter}, NSE = {-best_row['loss']:.3f}")

# Plot Obs vs Pred for the best iteration
plt.figure()
plt.scatter(best_row["obs"], best_row["pred"], alpha=0.6)
plt.plot(
    [best_row["obs"].min(), best_row["obs"].max()],
    [best_row["obs"].min(), best_row["obs"].max()],
    "k--"
)
plt.xlabel("Observed")
plt.ylabel("Predicted")
plt.title(f"Best iteration {best_iter}, NSE={-best_row['loss']:.3f}")
plt.show()
# Out:
# Best iteration: 22, NSE = 0.916

# %% [markdown]
# ## Parameter space analysis

# %%
from skopt.plots import plot_objective
from skopt.utils import create_result

res = create_result(
    Xi=opt.Xi,
    yi=np.array(opt.yi),
    space=opt.space,
    specs=None,
    models=opt.models
)

plot_objective(res)
# Out:
# <Axes: >

# %% [markdown]
# # Fit parameters for all cultivars

# %% [markdown]
# ## Run optimiser for all cultivars

# %%
CULTIVAR_FILE_DICT.keys()
# Out:
# dict_keys(['Ace', 'Blitz', 'Bolt', 'Digger', 'Greenfield', 'HallmarkXT', 'Jumbo2', 'KelpieXT', 'Nugget'])

# %%
Fitting_Variables = ['Lentil.Leaf.NodeNumber',
                     'Lentil.Phenology.MaturityDAS']

# ------------------------------------------------------------
# Parameter definitions
# ------------------------------------------------------------

param_config = [
    {
        "name": "[Phenology].MinFloralNodes.FixedValue",
        "short_name": "MinNod",
        "bounds": (0, 30),
        "step": 1,
        "initial": 15
    },
    {
        "name": "[Phenology].PpFloralNodes.FixedValue",
        "short_name": "MaxNod",
        "bounds": (0, 60),
        "step": 1,
        "initial": 30
    },
    {
        "name": "[Leaf].BasePhyllochron.FixedValue",
        "short_name": "BasPhy",
        "bounds": (10, 100),
        "step": 1,
        "initial": 30
    },
    {
        "name": '[Leaf].Phyllochron.EarlyVegetative.Phyllochron.EarlyLeafResponse.Decrease.Size.FixedValue',
        "short_name": "ElyPhy",
        "bounds": (0, .75),
        "step": 0.05,
        "initial": 0.3
    }
]

fits = pd.DataFrame(columns = ["best_x", "best_y", "STORE", "opt"])
for c in CULTIVAR_FILE_DICT.keys():
    fits.loc[c,["best_x", "best_y", "STORE", "opt"]] = fit_cultivar(
                                                                        CultivarToFit = c,
                                                                        ObsPredTableName = ["DailyObsPred","HarvestObsPred"],
                                                                        fitting_variables=Fitting_Variables,
                                                                        param_config=param_config,
                                                                        random_sample_size=19,
                                                                        stage_size=10,
                                                                        max_stages=5,
                                                                        shrink_factor=0.1,
                                                                        local_steps=10
                                                                    )
# Out:
# === Initial design: Ace ===
# [001] MinNod=15, MaxNod=30, BasPhy=30, ElyPhy=0.3 | Loss = 0.9838 | n = 79 | 14.0s
# [002] MinNod=11, MaxNod=17, BasPhy=72, ElyPhy=0.2 | Loss = -0.2874 | n = 79 | 14.0s
# [003] MinNod=29, MaxNod=37, BasPhy=50, ElyPhy=0.1 | Loss = 0.4962 | n = 79 | 14.0s
# [004] MinNod=22, MaxNod=8, BasPhy=21, ElyPhy=0.2 | Loss = 1.0000 | n = 79 | 14.0s
# [005] MinNod=18, MaxNod=18, BasPhy=55, ElyPhy=0.3 | Loss = -0.2074 | n = 79 | 14.0s
# [006] MinNod=5, MaxNod=22, BasPhy=13, ElyPhy=0.2 | Loss = 1.0000 | n = 76 | 14.0s
# [007] MinNod=5, MaxNod=27, BasPhy=92, ElyPhy=0.6 | Loss = -0.0701 | n = 79 | 15.0s
# [008] MinNod=2, MaxNod=47, BasPhy=33, ElyPhy=0.2 | Loss = 0.7730 | n = 79 | 14.0s
# [009] MinNod=26, MaxNod=12, BasPhy=70, ElyPhy=0.2 | Loss = 0.6789 | n = 79 | 15.0s
# [010] MinNod=18, MaxNod=31, BasPhy=38, ElyPhy=0.4 | Loss = 0.6147 | n = 79 | 15.0s
# [011] MinNod=21, MaxNod=36, BasPhy=57, ElyPhy=0.1 | Loss = 0.3143 | n = 79 | 14.0s
# [012] MinNod=1, MaxNod=3, BasPhy=59, ElyPhy=0.6 | Loss = 0.1584 | n = 75 | 14.0s
# [013] MinNod=29, MaxNod=36, BasPhy=27, ElyPhy=0.1 | Loss = 0.9887 | n = 79 | 15.0s
# [014] MinNod=25, MaxNod=10, BasPhy=97, ElyPhy=0.8 | Loss = 0.8684 | n = 79 | 14.0s
# [015] MinNod=6, MaxNod=4, BasPhy=80, ElyPhy=0.6 | Loss = -0.4649 | n = 79 | 14.0s
# [016] MinNod=5, MaxNod=57, BasPhy=95, ElyPhy=0.2 | Loss = 0.4138 | n = 79 | 15.0s
# [017] MinNod=6, MaxNod=58, BasPhy=91, ElyPhy=0.0 | Loss = 0.4149 | n = 79 | 14.0s
# [018] MinNod=9, MaxNod=49, BasPhy=64, ElyPhy=0.6 | Loss = -0.3453 | n = 79 | 15.0s
# [019] MinNod=16, MaxNod=18, BasPhy=93, ElyPhy=0.6 | Loss = 0.7874 | n = 79 | 15.0s
# [020] MinNod=13, MaxNod=6, BasPhy=18, ElyPhy=0.6 | Loss = 1.0000 | n = 78 | 15.0s
#
# === Stage 1 ===
# [021] MinNod=11, MaxNod=0, BasPhy=64, ElyPhy=0.8 | Loss = -0.6831 | n = 79 | 14.0s
# [022] MinNod=13, MaxNod=0, BasPhy=59, ElyPhy=0.8 | Loss = -0.5001 | n = 79 | 15.0s
# [023] MinNod=9, MaxNod=0, BasPhy=69, ElyPhy=0.8 | Loss = -0.6994 | n = 79 | 15.0s
# [024] MinNod=11, MaxNod=0, BasPhy=69, ElyPhy=0.8 | Loss = -0.6473 | n = 79 | 15.0s
# [025] MinNod=10, MaxNod=0, BasPhy=66, ElyPhy=0.6 | Loss = -0.6919 | n = 79 | 15.0s
# [026] MinNod=10, MaxNod=0, BasPhy=66, ElyPhy=0.8 | Loss = -0.7164 | n = 79 | 14.0s
# [027] MinNod=0, MaxNod=0, BasPhy=84, ElyPhy=0.8 | Loss = 0.5893 | n = 74 | 14.0s
# [028] MinNod=8, MaxNod=0, BasPhy=66, ElyPhy=0.8 | Loss = -0.7092 | n = 79 | 14.0s
# [029] MinNod=8, MaxNod=13, BasPhy=68, ElyPhy=0.8 | Loss = -0.7120 | n = 79 | 15.0s
# [030] MinNod=9, MaxNod=8, BasPhy=65, ElyPhy=0.8 | Loss = -0.7269 | n = 79 | 15.0s
#
# === Stage 2 ===
# [031] MinNod=8, MaxNod=0, BasPhy=59, ElyPhy=0.0 | Loss = -0.6662 | n = 79 | 14.0s
# [032] MinNod=8, MaxNod=0, BasPhy=59, ElyPhy=0.8 | Loss = -0.5299 | n = 79 | 14.0s
# [033] MinNod=7, MaxNod=0, BasPhy=65, ElyPhy=0.0 | Loss = -0.5776 | n = 79 | 14.0s
# [034] MinNod=11, MaxNod=0, BasPhy=59, ElyPhy=0.0 | Loss = -0.7056 | n = 79 | 15.0s
# [035] MinNod=10, MaxNod=13, BasPhy=59, ElyPhy=0.0 | Loss = -0.6973 | n = 79 | 15.0s
# [036] MinNod=10, MaxNod=0, BasPhy=61, ElyPhy=0.0 | Loss = -0.6947 | n = 79 | 15.0s
# [037] MinNod=11, MaxNod=0, BasPhy=55, ElyPhy=0.0 | Loss = -0.7356 | n = 79 | 15.0s
# [038] MinNod=13, MaxNod=0, BasPhy=53, ElyPhy=0.0 | Loss = -0.7149 | n = 79 | 14.0s
# [039] MinNod=12, MaxNod=9, BasPhy=55, ElyPhy=0.0 | Loss = -0.7051 | n = 79 | 15.0s
# [040] MinNod=30, MaxNod=0, BasPhy=47, ElyPhy=0.8 | Loss = 0.9822 | n = 79 | 15.0s
#
# === Stage 3 ===
# [041] MinNod=30, MaxNod=60, BasPhy=100, ElyPhy=0.0 | Loss = 0.8791 | n = 79 | 15.0s
# [042] MinNod=10, MaxNod=13, BasPhy=66, ElyPhy=0.8 | Loss = -0.6493 | n = 79 | 15.0s
# [043] MinNod=3, MaxNod=60, BasPhy=61, ElyPhy=0.0 | Loss = -0.5824 | n = 79 | 15.0s
# [044] MinNod=6, MaxNod=34, BasPhy=60, ElyPhy=0.0 | Loss = -0.6835 | n = 79 | 15.0s
# [045] MinNod=3, MaxNod=60, BasPhy=68, ElyPhy=0.8 | Loss = -0.5233 | n = 79 | 15.0s
# [046] MinNod=5, MaxNod=31, BasPhy=65, ElyPhy=0.4 | Loss = -0.6843 | n = 79 | 15.0s
# [047] MinNod=6, MaxNod=27, BasPhy=65, ElyPhy=0.8 | Loss = -0.7189 | n = 79 | 15.0s
# [048] MinNod=3, MaxNod=60, BasPhy=59, ElyPhy=0.8 | Loss = -0.4605 | n = 79 | 15.0s
# [049] MinNod=7, MaxNod=0, BasPhy=100, ElyPhy=0.8 | Loss = -0.0801 | n = 79 | 15.0s
# [050] MinNod=11, MaxNod=0, BasPhy=51, ElyPhy=0.0 | Loss = -0.7261 | n = 79 | 15.0s
# Stopping: loss stagnation
#
# === Global optimum ===
# Loss: -0.7356
#
# === Local refinement ===
# [051] MinNod=11, MaxNod=0, BasPhy=55, ElyPhy=0.0 | Loss = -0.7356 | n = 79 | 14.0s
# [052] MinNod=11, MaxNod=0, BasPhy=58, ElyPhy=0.0 | Loss = -0.7183 | n = 79 | 15.0s
# [053] MinNod=10, MaxNod=0, BasPhy=55, ElyPhy=0.0 | Loss = -0.7318 | n = 79 | 15.0s
# [054] MinNod=10, MaxNod=1, BasPhy=50, ElyPhy=0.0 | Loss = -0.7122 | n = 79 | 15.0s
# [055] MinNod=11, MaxNod=0, BasPhy=61, ElyPhy=0.0 | Loss = -0.6836 | n = 79 | 15.0s
# [056] MinNod=11, MaxNod=0, BasPhy=50, ElyPhy=0.0 | Loss = -0.7188 | n = 79 | 15.0s
# [057] MinNod=10, MaxNod=0, BasPhy=60, ElyPhy=0.0 | Loss = -0.7050 | n = 79 | 15.0s
# [058] MinNod=10, MaxNod=1, BasPhy=54, ElyPhy=0.0 | Loss = -0.7360 | n = 79 | 15.0s
# [059] MinNod=10, MaxNod=1, BasPhy=57, ElyPhy=0.0 | Loss = -0.7289 | n = 79 | 15.0s
# [060] MinNod=9, MaxNod=1, BasPhy=56, ElyPhy=0.0 | Loss = -0.7231 | n = 79 | 15.0s
# [061] MinNod=12, MaxNod=1, BasPhy=53, ElyPhy=0.0 | Loss = -0.7359 | n = 79 | 14.0s
#
# === Final result ===
# Loss: -0.7360
# MinNod: 10
# MaxNod: 1
# BasPhy: 54
# ElyPhy: 0.0
#
# === Initial design: Blitz ===
# [001] MinNod=15, MaxNod=30, BasPhy=30, ElyPhy=0.3 | Loss = 0.9976 | n = 87 | 15.0s
# [002] MinNod=11, MaxNod=17, BasPhy=72, ElyPhy=0.2 | Loss = -0.3372 | n = 88 | 15.0s
# [003] MinNod=29, MaxNod=37, BasPhy=50, ElyPhy=0.1 | Loss = 0.4321 | n = 89 | 15.0s
# [004] MinNod=22, MaxNod=8, BasPhy=21, ElyPhy=0.2 | Loss = 1.0000 | n = 87 | 15.0s
# [005] MinNod=18, MaxNod=18, BasPhy=55, ElyPhy=0.3 | Loss = -0.1422 | n = 89 | 15.0s
# [006] MinNod=5, MaxNod=22, BasPhy=13, ElyPhy=0.2 | Loss = 1.0000 | n = 81 | 15.0s
# [007] MinNod=5, MaxNod=27, BasPhy=92, ElyPhy=0.6 | Loss = -0.0867 | n = 88 | 15.0s
# [008] MinNod=2, MaxNod=47, BasPhy=33, ElyPhy=0.2 | Loss = 0.9218 | n = 87 | 15.0s
# [009] MinNod=26, MaxNod=12, BasPhy=70, ElyPhy=0.2 | Loss = 0.5106 | n = 89 | 15.0s
# [010] MinNod=18, MaxNod=31, BasPhy=38, ElyPhy=0.4 | Loss = 0.8484 | n = 88 | 15.0s
# [011] MinNod=21, MaxNod=36, BasPhy=57, ElyPhy=0.1 | Loss = 0.1964 | n = 89 | 15.0s
# [012] MinNod=1, MaxNod=3, BasPhy=59, ElyPhy=0.6 | Loss = 0.0366 | n = 78 | 14.0s
# [013] MinNod=29, MaxNod=36, BasPhy=27, ElyPhy=0.1 | Loss = 0.9987 | n = 88 | 15.0s
# [014] MinNod=25, MaxNod=10, BasPhy=97, ElyPhy=0.8 | Loss = 0.7791 | n = 89 | 15.0s
# [015] MinNod=6, MaxNod=4, BasPhy=80, ElyPhy=0.6 | Loss = -0.4929 | n = 87 | 15.0s
# [016] MinNod=5, MaxNod=57, BasPhy=95, ElyPhy=0.2 | Loss = 0.3138 | n = 89 | 15.0s
# [017] MinNod=6, MaxNod=58, BasPhy=91, ElyPhy=0.0 | Loss = 0.2988 | n = 89 | 15.0s
# [018] MinNod=9, MaxNod=49, BasPhy=64, ElyPhy=0.6 | Loss = -0.3673 | n = 88 | 14.0s
# [019] MinNod=16, MaxNod=18, BasPhy=93, ElyPhy=0.6 | Loss = 0.6756 | n = 89 | 15.0s
# [020] MinNod=13, MaxNod=6, BasPhy=18, ElyPhy=0.6 | Loss = 1.0000 | n = 83 | 14.0s
#
# === Stage 1 ===
# [021] MinNod=7, MaxNod=0, BasPhy=72, ElyPhy=0.8 | Loss = -0.6506 | n = 87 | 15.0s
# [022] MinNod=11, MaxNod=0, BasPhy=65, ElyPhy=0.8 | Loss = -0.6496 | n = 87 | 15.0s
# [023] MinNod=0, MaxNod=0, BasPhy=80, ElyPhy=0.8 | Loss = 0.4319 | n = 77 | 14.0s
# [024] MinNod=9, MaxNod=0, BasPhy=70, ElyPhy=0.8 | Loss = -0.6928 | n = 87 | 14.0s
# [025] MinNod=9, MaxNod=0, BasPhy=64, ElyPhy=0.5 | Loss = -0.7283 | n = 87 | 15.0s
# [026] MinNod=9, MaxNod=0, BasPhy=64, ElyPhy=0.8 | Loss = -0.6714 | n = 87 | 15.0s
# [027] MinNod=9, MaxNod=0, BasPhy=60, ElyPhy=0.0 | Loss = -0.7234 | n = 87 | 15.0s
# [028] MinNod=8, MaxNod=0, BasPhy=64, ElyPhy=0.1 | Loss = -0.6839 | n = 87 | 15.0s
# [029] MinNod=10, MaxNod=0, BasPhy=62, ElyPhy=0.3 | Loss = -0.7210 | n = 87 | 15.0s
# [030] MinNod=11, MaxNod=0, BasPhy=57, ElyPhy=0.8 | Loss = -0.2212 | n = 87 | 15.0s
#
# === Stage 2 ===
# [031] MinNod=12, MaxNod=0, BasPhy=61, ElyPhy=0.0 | Loss = -0.6748 | n = 87 | 14.0s
# [032] MinNod=9, MaxNod=0, BasPhy=66, ElyPhy=0.5 | Loss = -0.7047 | n = 87 | 15.0s
# [033] MinNod=8, MaxNod=0, BasPhy=61, ElyPhy=0.2 | Loss = -0.6075 | n = 87 | 15.0s
# [034] MinNod=10, MaxNod=0, BasPhy=63, ElyPhy=0.0 | Loss = -0.6929 | n = 87 | 15.0s
# [035] MinNod=9, MaxNod=0, BasPhy=67, ElyPhy=0.5 | Loss = -0.6982 | n = 87 | 15.0s
# [036] MinNod=9, MaxNod=0, BasPhy=68, ElyPhy=0.8 | Loss = -0.7100 | n = 87 | 16.0s
# [037] MinNod=10, MaxNod=0, BasPhy=64, ElyPhy=0.3 | Loss = -0.7035 | n = 87 | 15.0s
# [038] MinNod=9, MaxNod=0, BasPhy=78, ElyPhy=0.8 | Loss = -0.5002 | n = 87 | 15.0s
# [039] MinNod=8, MaxNod=0, BasPhy=67, ElyPhy=0.6 | Loss = -0.7054 | n = 87 | 15.0s
# [040] MinNod=12, MaxNod=0, BasPhy=61, ElyPhy=0.3 | Loss = -0.6883 | n = 87 | 15.0s
# Stopping: loss stagnation
#
# === Global optimum ===
# Loss: -0.7283
#
# === Local refinement ===
# [041] MinNod=9, MaxNod=0, BasPhy=64, ElyPhy=0.5 | Loss = -0.7283 | n = 87 | 15.0s
# [042] MinNod=9, MaxNod=0, BasPhy=67, ElyPhy=0.6 | Loss = -0.7045 | n = 87 | 15.0s
# [043] MinNod=8, MaxNod=0, BasPhy=63, ElyPhy=0.5 | Loss = -0.7196 | n = 87 | 15.0s
# [044] MinNod=8, MaxNod=1, BasPhy=58, ElyPhy=0.6 | Loss = -0.5879 | n = 87 | 14.0s
# [045] MinNod=9, MaxNod=0, BasPhy=70, ElyPhy=0.6 | Loss = -0.6567 | n = 87 | 16.0s
# [046] MinNod=9, MaxNod=0, BasPhy=58, ElyPhy=0.5 | Loss = -0.7074 | n = 87 | 15.0s
# [047] MinNod=8, MaxNod=0, BasPhy=70, ElyPhy=0.5 | Loss = -0.6542 | n = 87 | 15.0s
# [048] MinNod=8, MaxNod=1, BasPhy=62, ElyPhy=0.6 | Loss = -0.7306 | n = 87 | 15.0s
# [049] MinNod=8, MaxNod=1, BasPhy=66, ElyPhy=0.5 | Loss = -0.7134 | n = 87 | 14.0s
# [050] MinNod=8, MaxNod=1, BasPhy=65, ElyPhy=0.5 | Loss = -0.7229 | n = 87 | 14.0s
# [051] MinNod=8, MaxNod=1, BasPhy=64, ElyPhy=0.6 | Loss = -0.7316 | n = 87 | 15.0s
#
# === Final result ===
# Loss: -0.7316
# MinNod: 8
# MaxNod: 1
# BasPhy: 64
# ElyPhy: 0.55
#
# === Initial design: Bolt ===
# [001] MinNod=15, MaxNod=30, BasPhy=30, ElyPhy=0.3 | Loss = 0.9829 | n = 116 | 34.0s
# [002] MinNod=11, MaxNod=17, BasPhy=72, ElyPhy=0.2 | Loss = -0.3956 | n = 120 | 35.0s
# [003] MinNod=29, MaxNod=37, BasPhy=50, ElyPhy=0.1 | Loss = -0.0145 | n = 126 | 35.0s
# [004] MinNod=22, MaxNod=8, BasPhy=21, ElyPhy=0.2 | Loss = 1.0000 | n = 116 | 34.0s
# [005] MinNod=18, MaxNod=18, BasPhy=55, ElyPhy=0.3 | Loss = -0.4348 | n = 122 | 34.0s
# [006] MinNod=5, MaxNod=22, BasPhy=13, ElyPhy=0.2 | Loss = 1.0000 | n = 108 | 34.0s
# [007] MinNod=5, MaxNod=27, BasPhy=92, ElyPhy=0.6 | Loss = 0.0412 | n = 119 | 34.0s
# [008] MinNod=2, MaxNod=47, BasPhy=33, ElyPhy=0.2 | Loss = 0.7268 | n = 114 | 34.0s
# [009] MinNod=26, MaxNod=12, BasPhy=70, ElyPhy=0.2 | Loss = 0.1371 | n = 126 | 34.0s
# [010] MinNod=18, MaxNod=31, BasPhy=38, ElyPhy=0.4 | Loss = 0.5985 | n = 119 | 33.0s
# [011] MinNod=21, MaxNod=36, BasPhy=57, ElyPhy=0.1 | Loss = -0.2369 | n = 126 | 34.0s
# [012] MinNod=1, MaxNod=3, BasPhy=59, ElyPhy=0.6 | Loss = -0.0089 | n = 105 | 34.0s
# [013] MinNod=29, MaxNod=36, BasPhy=27, ElyPhy=0.1 | Loss = 0.9775 | n = 120 | 35.0s
# [014] MinNod=25, MaxNod=10, BasPhy=97, ElyPhy=0.8 | Loss = 0.5046 | n = 126 | 36.0s
# [015] MinNod=6, MaxNod=4, BasPhy=80, ElyPhy=0.6 | Loss = -0.2699 | n = 116 | 36.0s
# [016] MinNod=5, MaxNod=57, BasPhy=95, ElyPhy=0.2 | Loss = 0.1685 | n = 122 | 35.0s
# [017] MinNod=6, MaxNod=58, BasPhy=91, ElyPhy=0.0 | Loss = 0.1285 | n = 122 | 37.0s
# [018] MinNod=9, MaxNod=49, BasPhy=64, ElyPhy=0.6 | Loss = -0.5053 | n = 120 | 35.0s
# [019] MinNod=16, MaxNod=18, BasPhy=93, ElyPhy=0.6 | Loss = 0.3166 | n = 126 | 35.0s
# [020] MinNod=13, MaxNod=6, BasPhy=18, ElyPhy=0.6 | Loss = 1.0000 | n = 110 | 36.0s
#
# === Stage 1 ===
# [021] MinNod=13, MaxNod=0, BasPhy=62, ElyPhy=0.8 | Loss = -0.6985 | n = 119 | 35.0s
# [022] MinNod=13, MaxNod=0, BasPhy=59, ElyPhy=0.8 | Loss = -0.6155 | n = 118 | 34.0s
# [023] MinNod=14, MaxNod=0, BasPhy=64, ElyPhy=0.8 | Loss = -0.6883 | n = 120 | 36.0s
# [024] MinNod=12, MaxNod=0, BasPhy=65, ElyPhy=0.8 | Loss = -0.7439 | n = 118 | 36.0s
# [025] MinNod=11, MaxNod=0, BasPhy=63, ElyPhy=0.2 | Loss = -0.6482 | n = 116 | 35.0s
# [026] MinNod=9, MaxNod=0, BasPhy=66, ElyPhy=0.8 | Loss = -0.7279 | n = 116 | 36.0s
# [027] MinNod=0, MaxNod=60, BasPhy=75, ElyPhy=0.8 | Loss = -0.1261 | n = 118 | 36.0s
# [028] MinNod=29, MaxNod=1, BasPhy=54, ElyPhy=0.6 | Loss = -0.0092 | n = 126 | 36.0s
# [029] MinNod=0, MaxNod=1, BasPhy=99, ElyPhy=0.3 | Loss = 0.8169 | n = 102 | 35.0s
# [030] MinNod=11, MaxNod=12, BasPhy=65, ElyPhy=0.8 | Loss = -0.7030 | n = 119 | 35.0s
#
# === Stage 2 ===
# [031] MinNod=11, MaxNod=0, BasPhy=65, ElyPhy=0.6 | Loss = -0.4512 | n = 118 | 37.0s
# [032] MinNod=4, MaxNod=0, BasPhy=59, ElyPhy=0.0 | Loss = -0.2216 | n = 108 | 34.0s
# [033] MinNod=9, MaxNod=60, BasPhy=64, ElyPhy=0.3 | Loss = -0.3400 | n = 121 | 37.0s
# [034] MinNod=15, MaxNod=0, BasPhy=64, ElyPhy=0.8 | Loss = -0.6393 | n = 120 | 35.0s
# [035] MinNod=15, MaxNod=60, BasPhy=64, ElyPhy=0.8 | Loss = -0.2903 | n = 126 | 35.0s
# [036] MinNod=15, MaxNod=0, BasPhy=58, ElyPhy=0.1 | Loss = -0.6818 | n = 120 | 36.0s
# [037] MinNod=14, MaxNod=0, BasPhy=62, ElyPhy=0.0 | Loss = -0.6332 | n = 120 | 34.0s
# [038] MinNod=13, MaxNod=0, BasPhy=60, ElyPhy=0.8 | Loss = -0.6558 | n = 118 | 33.0s
# [039] MinNod=15, MaxNod=0, BasPhy=62, ElyPhy=0.8 | Loss = -0.6416 | n = 120 | 35.0s
# [040] MinNod=10, MaxNod=0, BasPhy=72, ElyPhy=0.8 | Loss = -0.3381 | n = 118 | 35.0s
# Stopping: loss stagnation
#
# === Global optimum ===
# Loss: -0.7439
#
# === Local refinement ===
# [041] MinNod=12, MaxNod=0, BasPhy=65, ElyPhy=0.8 | Loss = -0.7439 | n = 118 | 35.0s
# [042] MinNod=12, MaxNod=0, BasPhy=69, ElyPhy=0.7 | Loss = -0.6475 | n = 119 | 36.0s
# [043] MinNod=11, MaxNod=0, BasPhy=65, ElyPhy=0.7 | Loss = -0.4798 | n = 118 | 35.0s
# [044] MinNod=11, MaxNod=1, BasPhy=59, ElyPhy=0.8 | Loss = -0.6246 | n = 116 | 34.0s
# [045] MinNod=13, MaxNod=0, BasPhy=72, ElyPhy=0.7 | Loss = -0.5314 | n = 120 | 36.0s
# [046] MinNod=12, MaxNod=0, BasPhy=59, ElyPhy=0.7 | Loss = -0.4498 | n = 118 | 35.0s
# [047] MinNod=11, MaxNod=0, BasPhy=71, ElyPhy=0.7 | Loss = -0.6058 | n = 118 | 36.0s
# [048] MinNod=11, MaxNod=1, BasPhy=64, ElyPhy=0.8 | Loss = -0.4883 | n = 118 | 38.0s
# [049] MinNod=12, MaxNod=1, BasPhy=68, ElyPhy=0.7 | Loss = -0.6705 | n = 119 | 37.0s
# [050] MinNod=10, MaxNod=1, BasPhy=66, ElyPhy=0.7 | Loss = -0.7221 | n = 116 | 35.0s
# [051] MinNod=12, MaxNod=0, BasPhy=67, ElyPhy=0.8 | Loss = -0.7152 | n = 119 | 35.0s
#
# === Final result ===
# Loss: -0.7439
# MinNod: 12
# MaxNod: 0
# BasPhy: 65
# ElyPhy: 0.75
#
# === Initial design: Digger ===
# No valid data for variable 'Lentil.Phenology.MaturityDAS' after dropping NaNs
# [001] MinNod=15, MaxNod=30, BasPhy=30, ElyPhy=0.3 | Loss = 0.9927 | n = 24 | 15.0s
# No valid data for variable 'Lentil.Phenology.MaturityDAS' after dropping NaNs
# [002] MinNod=11, MaxNod=17, BasPhy=72, ElyPhy=0.2 | Loss = -0.2503 | n = 24 | 13.0s
# No valid data for variable 'Lentil.Phenology.MaturityDAS' after dropping NaNs
# [003] MinNod=29, MaxNod=37, BasPhy=50, ElyPhy=0.1 | Loss = -0.8991 | n = 24 | 14.0s
# No valid data for variable 'Lentil.Phenology.MaturityDAS' after dropping NaNs
# [004] MinNod=22, MaxNod=8, BasPhy=21, ElyPhy=0.2 | Loss = 1.0000 | n = 24 | 13.0s
# No valid data for variable 'Lentil.Phenology.MaturityDAS' after dropping NaNs
# [005] MinNod=18, MaxNod=18, BasPhy=55, ElyPhy=0.3 | Loss = -0.8785 | n = 24 | 15.0s
# No valid data for variable 'Lentil.Phenology.MaturityDAS' after dropping NaNs
# [006] MinNod=5, MaxNod=22, BasPhy=13, ElyPhy=0.2 | Loss = 1.0000 | n = 22 | 16.0s
# No valid data for variable 'Lentil.Phenology.MaturityDAS' after dropping NaNs
# [007] MinNod=5, MaxNod=27, BasPhy=92, ElyPhy=0.6 | Loss = 0.4374 | n = 24 | 14.0s
# No valid data for variable 'Lentil.Phenology.MaturityDAS' after dropping NaNs
# [008] MinNod=2, MaxNod=47, BasPhy=33, ElyPhy=0.2 | Loss = 0.6682 | n = 24 | 14.0s
# No valid data for variable 'Lentil.Phenology.MaturityDAS' after dropping NaNs
# [009] MinNod=26, MaxNod=12, BasPhy=70, ElyPhy=0.2 | Loss = -0.3380 | n = 24 | 15.0s
# No valid data for variable 'Lentil.Phenology.MaturityDAS' after dropping NaNs
# [010] MinNod=18, MaxNod=31, BasPhy=38, ElyPhy=0.4 | Loss = 0.3787 | n = 24 | 15.0s
# No valid data for variable 'Lentil.Phenology.MaturityDAS' after dropping NaNs
# [011] MinNod=21, MaxNod=36, BasPhy=57, ElyPhy=0.1 | Loss = -0.7711 | n = 24 | 15.0s
# No valid data for variable 'Lentil.Phenology.MaturityDAS' after dropping NaNs
# [012] MinNod=1, MaxNod=3, BasPhy=59, ElyPhy=0.6 | Loss = -0.8133 | n = 22 | 13.0s
# No valid data for variable 'Lentil.Phenology.MaturityDAS' after dropping NaNs
# [013] MinNod=29, MaxNod=36, BasPhy=27, ElyPhy=0.1 | Loss = 0.9883 | n = 24 | 14.0s
# No valid data for variable 'Lentil.Phenology.MaturityDAS' after dropping NaNs
# [014] MinNod=25, MaxNod=10, BasPhy=97, ElyPhy=0.8 | Loss = 0.5583 | n = 24 | 14.0s
# No valid data for variable 'Lentil.Phenology.MaturityDAS' after dropping NaNs
# [015] MinNod=6, MaxNod=4, BasPhy=80, ElyPhy=0.6 | Loss = 0.0134 | n = 24 | 14.0s
# No valid data for variable 'Lentil.Phenology.MaturityDAS' after dropping NaNs
# [016] MinNod=5, MaxNod=57, BasPhy=95, ElyPhy=0.2 | Loss = 0.5141 | n = 24 | 15.0s
# No valid data for variable 'Lentil.Phenology.MaturityDAS' after dropping NaNs
# [017] MinNod=6, MaxNod=58, BasPhy=91, ElyPhy=0.0 | Loss = 0.4142 | n = 24 | 14.0s
# No valid data for variable 'Lentil.Phenology.MaturityDAS' after dropping NaNs
# [018] MinNod=9, MaxNod=49, BasPhy=64, ElyPhy=0.6 | Loss = -0.7661 | n = 24 | 13.0s
# No valid data for variable 'Lentil.Phenology.MaturityDAS' after dropping NaNs
# [019] MinNod=16, MaxNod=18, BasPhy=93, ElyPhy=0.6 | Loss = 0.4642 | n = 24 | 14.0s
# No valid data for variable 'Lentil.Phenology.MaturityDAS' after dropping NaNs
# [020] MinNod=13, MaxNod=6, BasPhy=18, ElyPhy=0.6 | Loss = 1.0000 | n = 24 | 14.0s
#
# === Stage 1 ===
# No valid data for variable 'Lentil.Phenology.MaturityDAS' after dropping NaNs
# [021] MinNod=0, MaxNod=60, BasPhy=52, ElyPhy=0.8 | Loss = 0.1363 | n = 24 | 13.0s
# No valid data for variable 'Lentil.Phenology.MaturityDAS' after dropping NaNs
# [022] MinNod=0, MaxNod=0, BasPhy=51, ElyPhy=0.1 | Loss = -0.8122 | n = 22 | 14.0s
# No valid data for variable 'Lentil.Phenology.MaturityDAS' after dropping NaNs
# [023] MinNod=30, MaxNod=2, BasPhy=59, ElyPhy=0.4 | Loss = -0.8201 | n = 24 | 14.0s
# No valid data for variable 'Lentil.Phenology.MaturityDAS' after dropping NaNs
# [024] MinNod=30, MaxNod=26, BasPhy=51, ElyPhy=0.0 | Loss = -0.8787 | n = 24 | 14.0s
# No valid data for variable 'Lentil.Phenology.MaturityDAS' after dropping NaNs
# [025] MinNod=0, MaxNod=60, BasPhy=51, ElyPhy=0.0 | Loss = -0.8784 | n = 24 | 14.0s
# No valid data for variable 'Lentil.Phenology.MaturityDAS' after dropping NaNs
# [026] MinNod=30, MaxNod=60, BasPhy=47, ElyPhy=0.0 | Loss = -0.9071 | n = 24 | 15.0s
# No valid data for variable 'Lentil.Phenology.MaturityDAS' after dropping NaNs
# [027] MinNod=30, MaxNod=60, BasPhy=53, ElyPhy=0.2 | Loss = -0.8879 | n = 24 | 14.0s
# No valid data for variable 'Lentil.Phenology.MaturityDAS' after dropping NaNs
# [028] MinNod=30, MaxNod=60, BasPhy=56, ElyPhy=0.3 | Loss = -0.8583 | n = 24 | 15.0s
# No valid data for variable 'Lentil.Phenology.MaturityDAS' after dropping NaNs
# [029] MinNod=0, MaxNod=0, BasPhy=65, ElyPhy=0.8 | Loss = -0.7161 | n = 22 | 16.0s
# No valid data for variable 'Lentil.Phenology.MaturityDAS' after dropping NaNs
# [030] MinNod=0, MaxNod=0, BasPhy=58, ElyPhy=0.4 | Loss = -0.7103 | n = 22 | 15.0s
#
# === Stage 2 ===
# No valid data for variable 'Lentil.Phenology.MaturityDAS' after dropping NaNs
# [031] MinNod=30, MaxNod=60, BasPhy=49, ElyPhy=0.0 | Loss = -0.9013 | n = 24 | 15.0s
# No valid data for variable 'Lentil.Phenology.MaturityDAS' after dropping NaNs
# [032] MinNod=30, MaxNod=60, BasPhy=61, ElyPhy=0.7 | Loss = -0.8881 | n = 24 | 13.0s
# No valid data for variable 'Lentil.Phenology.MaturityDAS' after dropping NaNs
# [033] MinNod=30, MaxNod=60, BasPhy=49, ElyPhy=0.0 | Loss = -0.9013 | n = 24 | 15.0s
# No valid data for variable 'Lentil.Phenology.MaturityDAS' after dropping NaNs
# [034] MinNod=0, MaxNod=37, BasPhy=47, ElyPhy=0.0 | Loss = -0.9195 | n = 24 | 14.0s
# No valid data for variable 'Lentil.Phenology.MaturityDAS' after dropping NaNs
# [035] MinNod=30, MaxNod=0, BasPhy=61, ElyPhy=0.7 | Loss = -0.8880 | n = 24 | 15.0s
# No valid data for variable 'Lentil.Phenology.MaturityDAS' after dropping NaNs
# [036] MinNod=0, MaxNod=60, BasPhy=45, ElyPhy=0.0 | Loss = -0.9041 | n = 24 | 15.0s
# No valid data for variable 'Lentil.Phenology.MaturityDAS' after dropping NaNs
# [037] MinNod=30, MaxNod=0, BasPhy=52, ElyPhy=0.3 | Loss = -0.9147 | n = 24 | 14.0s
# No valid data for variable 'Lentil.Phenology.MaturityDAS' after dropping NaNs
# [038] MinNod=30, MaxNod=60, BasPhy=48, ElyPhy=0.2 | Loss = -0.9112 | n = 24 | 14.0s
# No valid data for variable 'Lentil.Phenology.MaturityDAS' after dropping NaNs
# [039] MinNod=13, MaxNod=60, BasPhy=47, ElyPhy=0.0 | Loss = -0.9065 | n = 24 | 14.0s
# No valid data for variable 'Lentil.Phenology.MaturityDAS' after dropping NaNs
# [040] MinNod=30, MaxNod=60, BasPhy=51, ElyPhy=0.2 | Loss = -0.9153 | n = 24 | 14.0s
#
# === Stage 3 ===
# No valid data for variable 'Lentil.Phenology.MaturityDAS' after dropping NaNs
# [041] MinNod=30, MaxNod=0, BasPhy=45, ElyPhy=0.0 | Loss = -0.8907 | n = 24 | 13.0s
# No valid data for variable 'Lentil.Phenology.MaturityDAS' after dropping NaNs
# [042] MinNod=30, MaxNod=0, BasPhy=60, ElyPhy=0.6 | Loss = -0.8811 | n = 24 | 13.0s
# No valid data for variable 'Lentil.Phenology.MaturityDAS' after dropping NaNs
# [043] MinNod=30, MaxNod=0, BasPhy=65, ElyPhy=0.8 | Loss = -0.8407 | n = 24 | 14.0s
# No valid data for variable 'Lentil.Phenology.MaturityDAS' after dropping NaNs
# [044] MinNod=30, MaxNod=0, BasPhy=49, ElyPhy=0.2 | Loss = -0.9134 | n = 24 | 14.0s
# No valid data for variable 'Lentil.Phenology.MaturityDAS' after dropping NaNs
# [045] MinNod=30, MaxNod=60, BasPhy=56, ElyPhy=0.5 | Loss = -0.9098 | n = 24 | 15.0s
# No valid data for variable 'Lentil.Phenology.MaturityDAS' after dropping NaNs
# [046] MinNod=20, MaxNod=60, BasPhy=58, ElyPhy=0.6 | Loss = -0.8977 | n = 24 | 15.0s
# No valid data for variable 'Lentil.Phenology.MaturityDAS' after dropping NaNs
# [047] MinNod=26, MaxNod=60, BasPhy=54, ElyPhy=0.4 | Loss = -0.9127 | n = 24 | 14.0s
# No valid data for variable 'Lentil.Phenology.MaturityDAS' after dropping NaNs
# [048] MinNod=23, MaxNod=0, BasPhy=56, ElyPhy=0.5 | Loss = -0.9011 | n = 24 | 15.0s
# No valid data for variable 'Lentil.Phenology.MaturityDAS' after dropping NaNs
# [049] MinNod=17, MaxNod=60, BasPhy=62, ElyPhy=0.8 | Loss = -0.8734 | n = 24 | 14.0s
# No valid data for variable 'Lentil.Phenology.MaturityDAS' after dropping NaNs
# [050] MinNod=0, MaxNod=41, BasPhy=62, ElyPhy=0.0 | Loss = -0.5636 | n = 24 | 14.0s
# Stopping: loss stagnation
#
# === Global optimum ===
# Loss: -0.9195
#
# === Local refinement ===
# No valid data for variable 'Lentil.Phenology.MaturityDAS' after dropping NaNs
# [051] MinNod=0, MaxNod=37, BasPhy=47, ElyPhy=0.0 | Loss = -0.9195 | n = 24 | 14.0s
# No valid data for variable 'Lentil.Phenology.MaturityDAS' after dropping NaNs
# [052] MinNod=1, MaxNod=35, BasPhy=49, ElyPhy=0.0 | Loss = -0.9026 | n = 24 | 14.0s
# No valid data for variable 'Lentil.Phenology.MaturityDAS' after dropping NaNs
# [053] MinNod=0, MaxNod=34, BasPhy=46, ElyPhy=0.0 | Loss = -0.9218 | n = 24 | 15.0s
# No valid data for variable 'Lentil.Phenology.MaturityDAS' after dropping NaNs
# [054] MinNod=0, MaxNod=38, BasPhy=42, ElyPhy=0.0 | Loss = -0.8789 | n = 24 | 13.0s
# No valid data for variable 'Lentil.Phenology.MaturityDAS' after dropping NaNs
# [055] MinNod=1, MaxNod=33, BasPhy=51, ElyPhy=0.0 | Loss = -0.8694 | n = 24 | 14.0s
# No valid data for variable 'Lentil.Phenology.MaturityDAS' after dropping NaNs
# [056] MinNod=0, MaxNod=33, BasPhy=42, ElyPhy=0.0 | Loss = -0.8832 | n = 24 | 13.0s
# No valid data for variable 'Lentil.Phenology.MaturityDAS' after dropping NaNs
# [057] MinNod=0, MaxNod=34, BasPhy=51, ElyPhy=0.0 | Loss = -0.8637 | n = 24 | 13.0s
# No valid data for variable 'Lentil.Phenology.MaturityDAS' after dropping NaNs
# [058] MinNod=0, MaxNod=38, BasPhy=45, ElyPhy=0.0 | Loss = -0.9211 | n = 24 | 15.0s
# No valid data for variable 'Lentil.Phenology.MaturityDAS' after dropping NaNs
# [059] MinNod=0, MaxNod=40, BasPhy=48, ElyPhy=0.0 | Loss = -0.9128 | n = 24 | 14.0s
# No valid data for variable 'Lentil.Phenology.MaturityDAS' after dropping NaNs
# [060] MinNod=0, MaxNod=40, BasPhy=47, ElyPhy=0.0 | Loss = -0.9202 | n = 24 | 15.0s
# No valid data for variable 'Lentil.Phenology.MaturityDAS' after dropping NaNs
# [061] MinNod=1, MaxNod=40, BasPhy=47, ElyPhy=0.0 | Loss = -0.9201 | n = 24 | 14.0s
#
# === Final result ===
# Loss: -0.9218
# MinNod: 0
# MaxNod: 34
# BasPhy: 46
# ElyPhy: 0.0
#
# === Initial design: Greenfield ===
# [001] MinNod=15, MaxNod=30, BasPhy=30, ElyPhy=0.3 | Loss = 1.0000 | n = 79 | 14.0s
# [002] MinNod=11, MaxNod=17, BasPhy=72, ElyPhy=0.2 | Loss = -0.6229 | n = 79 | 15.0s
# [003] MinNod=29, MaxNod=37, BasPhy=50, ElyPhy=0.1 | Loss = 0.0480 | n = 79 | 16.0s
# [004] MinNod=22, MaxNod=8, BasPhy=21, ElyPhy=0.2 | Loss = 1.0000 | n = 79 | 15.0s
# [005] MinNod=18, MaxNod=18, BasPhy=55, ElyPhy=0.3 | Loss = -0.5274 | n = 79 | 14.0s
# [006] MinNod=5, MaxNod=22, BasPhy=13, ElyPhy=0.2 | Loss = 1.0000 | n = 74 | 14.0s
# [007] MinNod=5, MaxNod=27, BasPhy=92, ElyPhy=0.6 | Loss = -0.2244 | n = 79 | 15.0s
# [008] MinNod=2, MaxNod=47, BasPhy=33, ElyPhy=0.2 | Loss = 0.9981 | n = 79 | 14.0s
# [009] MinNod=26, MaxNod=12, BasPhy=70, ElyPhy=0.2 | Loss = 0.0801 | n = 79 | 16.0s
# [010] MinNod=18, MaxNod=31, BasPhy=38, ElyPhy=0.4 | Loss = 0.9832 | n = 79 | 14.0s
# [011] MinNod=21, MaxNod=36, BasPhy=57, ElyPhy=0.1 | Loss = -0.2998 | n = 79 | 15.0s
# [012] MinNod=1, MaxNod=3, BasPhy=59, ElyPhy=0.6 | Loss = 0.0818 | n = 71 | 14.0s
# [013] MinNod=29, MaxNod=36, BasPhy=27, ElyPhy=0.1 | Loss = 1.0000 | n = 79 | 15.0s
# [014] MinNod=25, MaxNod=10, BasPhy=97, ElyPhy=0.8 | Loss = 0.6092 | n = 79 | 14.0s
# [015] MinNod=6, MaxNod=4, BasPhy=80, ElyPhy=0.6 | Loss = -0.5142 | n = 79 | 14.0s
# [016] MinNod=5, MaxNod=57, BasPhy=95, ElyPhy=0.2 | Loss = 0.0587 | n = 79 | 15.0s
# [017] MinNod=6, MaxNod=58, BasPhy=91, ElyPhy=0.0 | Loss = -0.0032 | n = 79 | 15.0s
# [018] MinNod=9, MaxNod=49, BasPhy=64, ElyPhy=0.6 | Loss = -0.6573 | n = 79 | 16.0s
# [019] MinNod=16, MaxNod=18, BasPhy=93, ElyPhy=0.6 | Loss = 0.4039 | n = 79 | 15.0s
# [020] MinNod=13, MaxNod=6, BasPhy=18, ElyPhy=0.6 | Loss = 1.0000 | n = 76 | 15.0s
#
# === Stage 1 ===
# [021] MinNod=12, MaxNod=3, BasPhy=66, ElyPhy=0.8 | Loss = -0.7374 | n = 79 | 16.0s
# [022] MinNod=14, MaxNod=60, BasPhy=64, ElyPhy=0.8 | Loss = -0.2570 | n = 79 | 16.0s
# [023] MinNod=11, MaxNod=21, BasPhy=64, ElyPhy=0.2 | Loss = -0.7517 | n = 79 | 17.0s
# [024] MinNod=5, MaxNod=36, BasPhy=70, ElyPhy=0.8 | Loss = -0.7931 | n = 79 | 14.0s
# [025] MinNod=0, MaxNod=60, BasPhy=72, ElyPhy=0.0 | Loss = -0.6482 | n = 79 | 17.0s
# [026] MinNod=16, MaxNod=0, BasPhy=60, ElyPhy=0.0 | Loss = -0.7540 | n = 79 | 15.0s
# [027] MinNod=0, MaxNod=24, BasPhy=76, ElyPhy=0.6 | Loss = -0.6226 | n = 79 | 16.0s
# [028] MinNod=7, MaxNod=27, BasPhy=68, ElyPhy=0.0 | Loss = -0.7359 | n = 79 | 14.0s
# [029] MinNod=5, MaxNod=46, BasPhy=71, ElyPhy=0.8 | Loss = -0.7334 | n = 79 | 14.0s
# [030] MinNod=15, MaxNod=10, BasPhy=62, ElyPhy=0.8 | Loss = -0.4252 | n = 79 | 15.0s
#
# === Stage 2 ===
# [031] MinNod=10, MaxNod=0, BasPhy=66, ElyPhy=0.0 | Loss = -0.7425 | n = 79 | 13.0s
# [032] MinNod=7, MaxNod=0, BasPhy=70, ElyPhy=0.7 | Loss = -0.6864 | n = 79 | 14.0s
# [033] MinNod=2, MaxNod=60, BasPhy=75, ElyPhy=0.8 | Loss = -0.6246 | n = 79 | 14.0s
# [034] MinNod=12, MaxNod=0, BasPhy=63, ElyPhy=0.0 | Loss = -0.7853 | n = 79 | 15.0s
# [035] MinNod=6, MaxNod=60, BasPhy=67, ElyPhy=0.0 | Loss = -0.6254 | n = 79 | 15.0s
# [036] MinNod=7, MaxNod=25, BasPhy=69, ElyPhy=0.5 | Loss = -0.7715 | n = 79 | 16.0s
# [037] MinNod=0, MaxNod=60, BasPhy=68, ElyPhy=0.8 | Loss = -0.7741 | n = 79 | 16.0s
# [038] MinNod=6, MaxNod=36, BasPhy=67, ElyPhy=0.8 | Loss = -0.7592 | n = 79 | 14.0s
# [039] MinNod=0, MaxNod=0, BasPhy=100, ElyPhy=0.0 | Loss = 0.8375 | n = 70 | 15.0s
# [040] MinNod=16, MaxNod=0, BasPhy=56, ElyPhy=0.0 | Loss = -0.7535 | n = 79 | 14.0s
# Stopping: loss stagnation
#
# === Global optimum ===
# Loss: -0.7931
#
# === Local refinement ===
# [041] MinNod=5, MaxNod=36, BasPhy=70, ElyPhy=0.8 | Loss = -0.7931 | n = 79 | 15.0s
# [042] MinNod=6, MaxNod=34, BasPhy=74, ElyPhy=0.7 | Loss = -0.6829 | n = 79 | 16.0s
# [043] MinNod=5, MaxNod=33, BasPhy=69, ElyPhy=0.7 | Loss = -0.8082 | n = 79 | 15.0s
# [044] MinNod=5, MaxNod=37, BasPhy=63, ElyPhy=0.8 | Loss = -0.5931 | n = 79 | 15.0s
# [045] MinNod=6, MaxNod=33, BasPhy=76, ElyPhy=0.7 | Loss = -0.6240 | n = 79 | 15.0s
# [046] MinNod=5, MaxNod=33, BasPhy=63, ElyPhy=0.7 | Loss = -0.7068 | n = 79 | 17.0s
# [047] MinNod=5, MaxNod=33, BasPhy=76, ElyPhy=0.7 | Loss = -0.6505 | n = 79 | 15.0s
# [048] MinNod=5, MaxNod=37, BasPhy=68, ElyPhy=0.8 | Loss = -0.7856 | n = 79 | 15.0s
# [049] MinNod=5, MaxNod=39, BasPhy=72, ElyPhy=0.7 | Loss = -0.7391 | n = 79 | 15.0s
# [050] MinNod=4, MaxNod=39, BasPhy=70, ElyPhy=0.7 | Loss = -0.7938 | n = 79 | 15.0s
# [051] MinNod=4, MaxNod=33, BasPhy=69, ElyPhy=0.8 | Loss = -0.8145 | n = 79 | 14.0s
#
# === Final result ===
# Loss: -0.8145
# MinNod: 4
# MaxNod: 33
# BasPhy: 69
# ElyPhy: 0.75
#
# === Initial design: HallmarkXT ===
# [001] MinNod=15, MaxNod=30, BasPhy=30, ElyPhy=0.3 | Loss = 0.9883 | n = 112 | 37.0s
# [002] MinNod=11, MaxNod=17, BasPhy=72, ElyPhy=0.2 | Loss = -0.4989 | n = 116 | 38.0s
# [003] MinNod=29, MaxNod=37, BasPhy=50, ElyPhy=0.1 | Loss = -0.0999 | n = 122 | 37.0s
# [004] MinNod=22, MaxNod=8, BasPhy=21, ElyPhy=0.2 | Loss = 1.0000 | n = 112 | 35.0s
# [005] MinNod=18, MaxNod=18, BasPhy=55, ElyPhy=0.3 | Loss = -0.5105 | n = 118 | 37.0s
# [006] MinNod=5, MaxNod=22, BasPhy=13, ElyPhy=0.2 | Loss = 1.0000 | n = 104 | 38.0s
# [007] MinNod=5, MaxNod=27, BasPhy=92, ElyPhy=0.6 | Loss = -0.1312 | n = 115 | 36.0s
# [008] MinNod=2, MaxNod=47, BasPhy=33, ElyPhy=0.2 | Loss = 0.8163 | n = 110 | 38.0s
# [009] MinNod=26, MaxNod=12, BasPhy=70, ElyPhy=0.2 | Loss = -0.0799 | n = 122 | 36.0s
# [010] MinNod=18, MaxNod=31, BasPhy=38, ElyPhy=0.4 | Loss = 0.6123 | n = 115 | 35.0s
# [011] MinNod=21, MaxNod=36, BasPhy=57, ElyPhy=0.1 | Loss = -0.3377 | n = 122 | 39.0s
# [012] MinNod=1, MaxNod=3, BasPhy=59, ElyPhy=0.6 | Loss = 0.1581 | n = 101 | 37.0s
# [013] MinNod=29, MaxNod=36, BasPhy=27, ElyPhy=0.1 | Loss = 0.9831 | n = 116 | 37.0s
# [014] MinNod=25, MaxNod=10, BasPhy=97, ElyPhy=0.8 | Loss = 0.3050 | n = 122 | 37.0s
# [015] MinNod=6, MaxNod=4, BasPhy=80, ElyPhy=0.6 | Loss = -0.3419 | n = 112 | 37.0s
# [016] MinNod=5, MaxNod=57, BasPhy=95, ElyPhy=0.2 | Loss = 0.0693 | n = 118 | 38.0s
# [017] MinNod=6, MaxNod=58, BasPhy=91, ElyPhy=0.0 | Loss = 0.0279 | n = 118 | 38.0s
# [018] MinNod=9, MaxNod=49, BasPhy=64, ElyPhy=0.6 | Loss = -0.5764 | n = 116 | 38.0s
# [019] MinNod=16, MaxNod=18, BasPhy=93, ElyPhy=0.6 | Loss = 0.1649 | n = 122 | 37.0s
# [020] MinNod=13, MaxNod=6, BasPhy=18, ElyPhy=0.6 | Loss = 1.0000 | n = 106 | 36.0s
#
# === Stage 1 ===
# [021] MinNod=14, MaxNod=10, BasPhy=64, ElyPhy=0.8 | Loss = -0.6565 | n = 116 | 37.0s
# [022] MinNod=14, MaxNod=60, BasPhy=63, ElyPhy=0.8 | Loss = -0.0990 | n = 120 | 37.0s
# [023] MinNod=11, MaxNod=27, BasPhy=63, ElyPhy=0.8 | Loss = -0.6473 | n = 116 | 37.0s
# [024] MinNod=2, MaxNod=46, BasPhy=68, ElyPhy=0.8 | Loss = -0.7229 | n = 112 | 38.0s
# [025] MinNod=0, MaxNod=60, BasPhy=66, ElyPhy=0.0 | Loss = -0.5982 | n = 112 | 38.0s
# [026] MinNod=4, MaxNod=41, BasPhy=66, ElyPhy=0.0 | Loss = -0.6168 | n = 112 | 36.0s
# [027] MinNod=0, MaxNod=54, BasPhy=72, ElyPhy=0.8 | Loss = -0.6086 | n = 112 | 38.0s
# [028] MinNod=2, MaxNod=49, BasPhy=65, ElyPhy=0.8 | Loss = -0.7446 | n = 112 | 38.0s
# [029] MinNod=24, MaxNod=0, BasPhy=57, ElyPhy=0.8 | Loss = -0.1327 | n = 122 | 38.0s
# [030] MinNod=0, MaxNod=48, BasPhy=65, ElyPhy=0.8 | Loss = -0.7459 | n = 112 | 37.0s
#
# === Stage 2 ===
# [031] MinNod=0, MaxNod=0, BasPhy=100, ElyPhy=0.8 | Loss = 0.8141 | n = 98 | 35.0s
# [032] MinNod=0, MaxNod=54, BasPhy=61, ElyPhy=0.8 | Loss = -0.6833 | n = 112 | 38.0s
# [033] MinNod=30, MaxNod=60, BasPhy=100, ElyPhy=0.8 | Loss = 0.3437 | n = 122 | 38.0s
# [034] MinNod=0, MaxNod=31, BasPhy=75, ElyPhy=0.8 | Loss = -0.4889 | n = 110 | 38.0s
# [035] MinNod=0, MaxNod=52, BasPhy=65, ElyPhy=0.8 | Loss = -0.7436 | n = 112 | 38.0s
# [036] MinNod=16, MaxNod=20, BasPhy=62, ElyPhy=0.8 | Loss = -0.4690 | n = 118 | 38.0s
# [037] MinNod=15, MaxNod=0, BasPhy=61, ElyPhy=0.0 | Loss = -0.6965 | n = 116 | 38.0s
# [038] MinNod=13, MaxNod=17, BasPhy=60, ElyPhy=0.0 | Loss = -0.6741 | n = 116 | 37.0s
# [039] MinNod=5, MaxNod=38, BasPhy=65, ElyPhy=0.8 | Loss = -0.7495 | n = 112 | 37.0s
# [040] MinNod=3, MaxNod=44, BasPhy=64, ElyPhy=0.6 | Loss = -0.7345 | n = 112 | 37.0s
#
# === Stage 3 ===
# [041] MinNod=11, MaxNod=0, BasPhy=67, ElyPhy=0.8 | Loss = -0.5168 | n = 114 | 38.0s
# [042] MinNod=13, MaxNod=3, BasPhy=58, ElyPhy=0.6 | Loss = -0.7643 | n = 114 | 38.0s
# [043] MinNod=14, MaxNod=0, BasPhy=55, ElyPhy=0.0 | Loss = -0.7852 | n = 114 | 38.0s
# [044] MinNod=30, MaxNod=60, BasPhy=65, ElyPhy=0.0 | Loss = -0.0912 | n = 122 | 38.0s
# [045] MinNod=13, MaxNod=3, BasPhy=57, ElyPhy=0.0 | Loss = -0.7765 | n = 114 | 38.0s
# [046] MinNod=13, MaxNod=0, BasPhy=53, ElyPhy=0.4 | Loss = -0.7477 | n = 112 | 38.0s
# [047] MinNod=14, MaxNod=5, BasPhy=55, ElyPhy=0.0 | Loss = -0.7749 | n = 115 | 38.0s
# [048] MinNod=6, MaxNod=37, BasPhy=59, ElyPhy=0.8 | Loss = -0.5975 | n = 112 | 38.0s
# [049] MinNod=14, MaxNod=1, BasPhy=56, ElyPhy=0.2 | Loss = -0.7437 | n = 115 | 38.0s
# [050] MinNod=13, MaxNod=0, BasPhy=56, ElyPhy=0.0 | Loss = -0.5244 | n = 114 | 37.0s
#
# === Stage 4 ===
# [051] MinNod=14, MaxNod=0, BasPhy=55, ElyPhy=0.8 | Loss = -0.2741 | n = 114 | 38.0s
# [052] MinNod=12, MaxNod=11, BasPhy=61, ElyPhy=0.3 | Loss = -0.7528 | n = 115 | 38.0s
# [053] MinNod=13, MaxNod=9, BasPhy=60, ElyPhy=0.3 | Loss = -0.5493 | n = 116 | 37.0s
# [054] MinNod=6, MaxNod=37, BasPhy=70, ElyPhy=0.8 | Loss = -0.6332 | n = 115 | 37.0s
# [055] MinNod=0, MaxNod=60, BasPhy=66, ElyPhy=0.8 | Loss = -0.7311 | n = 112 | 39.0s
# [056] MinNod=17, MaxNod=0, BasPhy=56, ElyPhy=0.0 | Loss = -0.7089 | n = 116 | 38.0s
# [057] MinNod=2, MaxNod=60, BasPhy=66, ElyPhy=0.8 | Loss = -0.4629 | n = 114 | 37.0s
# [058] MinNod=15, MaxNod=0, BasPhy=60, ElyPhy=0.0 | Loss = -0.7099 | n = 116 | 38.0s
# [059] MinNod=0, MaxNod=44, BasPhy=65, ElyPhy=0.4 | Loss = -0.6811 | n = 112 | 37.0s
# [060] MinNod=12, MaxNod=17, BasPhy=58, ElyPhy=0.0 | Loss = -0.7431 | n = 115 | 38.0s
# Stopping: loss stagnation
#
# === Global optimum ===
# Loss: -0.7852
#
# === Local refinement ===
# [061] MinNod=14, MaxNod=0, BasPhy=55, ElyPhy=0.0 | Loss = -0.7852 | n = 114 | 37.0s
# [062] MinNod=15, MaxNod=0, BasPhy=58, ElyPhy=0.0 | Loss = -0.7354 | n = 116 | 37.0s
# [063] MinNod=14, MaxNod=0, BasPhy=55, ElyPhy=0.0 | Loss = -0.7852 | n = 114 | 38.0s
# [064] MinNod=13, MaxNod=1, BasPhy=50, ElyPhy=0.0 | Loss = -0.7646 | n = 112 | 37.0s
# [065] MinNod=15, MaxNod=0, BasPhy=61, ElyPhy=0.0 | Loss = -0.6965 | n = 116 | 37.0s
# [066] MinNod=14, MaxNod=0, BasPhy=50, ElyPhy=0.0 | Loss = -0.7669 | n = 112 | 35.0s
# [067] MinNod=14, MaxNod=0, BasPhy=60, ElyPhy=0.0 | Loss = -0.5430 | n = 116 | 36.0s
# [068] MinNod=13, MaxNod=1, BasPhy=54, ElyPhy=0.0 | Loss = -0.7803 | n = 112 | 37.0s
# [069] MinNod=14, MaxNod=1, BasPhy=57, ElyPhy=0.0 | Loss = -0.7681 | n = 115 | 37.0s
# [070] MinNod=13, MaxNod=1, BasPhy=56, ElyPhy=0.0 | Loss = -0.5250 | n = 114 | 37.0s
# [071] MinNod=14, MaxNod=0, BasPhy=55, ElyPhy=0.0 | Loss = -0.7852 | n = 114 | 37.0s
#
# === Final result ===
# Loss: -0.7852
# MinNod: 14
# MaxNod: 0
# BasPhy: 55
# ElyPhy: 0.0
#
# === Initial design: Jumbo2 ===
# [001] MinNod=15, MaxNod=30, BasPhy=30, ElyPhy=0.3 | Loss = 0.9150 | n = 175 | 42.0s
# [002] MinNod=11, MaxNod=17, BasPhy=72, ElyPhy=0.2 | Loss = -0.2462 | n = 179 | 43.0s
# [003] MinNod=29, MaxNod=37, BasPhy=50, ElyPhy=0.1 | Loss = 0.0196 | n = 187 | 44.0s
# [004] MinNod=22, MaxNod=8, BasPhy=21, ElyPhy=0.2 | Loss = 1.0000 | n = 171 | 44.0s
# [005] MinNod=18, MaxNod=18, BasPhy=55, ElyPhy=0.3 | Loss = -0.4068 | n = 181 | 43.0s
# [006] MinNod=5, MaxNod=22, BasPhy=13, ElyPhy=0.2 | Loss = 1.0000 | n = 157 | 41.0s
# [007] MinNod=5, MaxNod=27, BasPhy=92, ElyPhy=0.6 | Loss = 0.1545 | n = 178 | 44.0s
# [008] MinNod=2, MaxNod=47, BasPhy=33, ElyPhy=0.2 | Loss = 0.6489 | n = 169 | 46.0s
# [009] MinNod=26, MaxNod=12, BasPhy=70, ElyPhy=0.2 | Loss = 0.2151 | n = 187 | 44.0s
# [010] MinNod=18, MaxNod=31, BasPhy=38, ElyPhy=0.4 | Loss = 0.3495 | n = 178 | 44.0s
# [011] MinNod=21, MaxNod=36, BasPhy=57, ElyPhy=0.1 | Loss = -0.1642 | n = 187 | 44.0s
# [012] MinNod=1, MaxNod=3, BasPhy=59, ElyPhy=0.6 | Loss = -0.0657 | n = 153 | 42.0s
# [013] MinNod=29, MaxNod=36, BasPhy=27, ElyPhy=0.1 | Loss = 0.9824 | n = 179 | 45.0s
# [014] MinNod=25, MaxNod=10, BasPhy=97, ElyPhy=0.8 | Loss = 0.6437 | n = 187 | 42.0s
# [015] MinNod=6, MaxNod=4, BasPhy=80, ElyPhy=0.6 | Loss = -0.0625 | n = 171 | 43.0s
# [016] MinNod=5, MaxNod=57, BasPhy=95, ElyPhy=0.2 | Loss = 0.3893 | n = 181 | 45.0s
# [017] MinNod=6, MaxNod=58, BasPhy=91, ElyPhy=0.0 | Loss = 0.3480 | n = 181 | 48.0s
# [018] MinNod=9, MaxNod=49, BasPhy=64, ElyPhy=0.6 | Loss = -0.4650 | n = 179 | 45.0s
# [019] MinNod=16, MaxNod=18, BasPhy=93, ElyPhy=0.6 | Loss = 0.5150 | n = 187 | 44.0s
# [020] MinNod=13, MaxNod=6, BasPhy=18, ElyPhy=0.6 | Loss = 1.0000 | n = 162 | 46.0s
#
# === Stage 1 ===
# [021] MinNod=14, MaxNod=15, BasPhy=59, ElyPhy=0.8 | Loss = -0.5288 | n = 179 | 44.0s
# [022] MinNod=13, MaxNod=60, BasPhy=56, ElyPhy=0.8 | Loss = -0.1778 | n = 181 | 46.0s
# [023] MinNod=10, MaxNod=27, BasPhy=61, ElyPhy=0.8 | Loss = -0.6239 | n = 178 | 45.0s
# [024] MinNod=7, MaxNod=33, BasPhy=60, ElyPhy=0.8 | Loss = -0.6690 | n = 177 | 43.0s
# [025] MinNod=0, MaxNod=42, BasPhy=64, ElyPhy=0.8 | Loss = -0.5014 | n = 174 | 44.0s
# [026] MinNod=7, MaxNod=33, BasPhy=58, ElyPhy=0.0 | Loss = -0.5258 | n = 177 | 44.0s
# [027] MinNod=8, MaxNod=33, BasPhy=57, ElyPhy=0.8 | Loss = -0.5634 | n = 177 | 45.0s
# [028] MinNod=6, MaxNod=31, BasPhy=63, ElyPhy=0.8 | Loss = -0.7119 | n = 175 | 44.0s
# [029] MinNod=5, MaxNod=28, BasPhy=63, ElyPhy=0.8 | Loss = -0.7251 | n = 175 | 42.0s
# [030] MinNod=30, MaxNod=0, BasPhy=50, ElyPhy=0.8 | Loss = 0.6699 | n = 187 | 43.0s
#
# === Stage 2 ===
# [031] MinNod=2, MaxNod=28, BasPhy=67, ElyPhy=0.8 | Loss = -0.5334 | n = 173 | 45.0s
# [032] MinNod=6, MaxNod=25, BasPhy=62, ElyPhy=0.8 | Loss = -0.7303 | n = 175 | 43.0s
# [033] MinNod=0, MaxNod=0, BasPhy=100, ElyPhy=0.5 | Loss = 0.9078 | n = 150 | 42.0s
# [034] MinNod=30, MaxNod=60, BasPhy=76, ElyPhy=0.8 | Loss = 0.3063 | n = 187 | 46.0s
# [035] MinNod=0, MaxNod=60, BasPhy=56, ElyPhy=0.8 | Loss = -0.5615 | n = 174 | 44.0s
# [036] MinNod=3, MaxNod=60, BasPhy=63, ElyPhy=0.8 | Loss = -0.6462 | n = 177 | 53.0s
# [037] MinNod=6, MaxNod=21, BasPhy=64, ElyPhy=0.8 | Loss = -0.7201 | n = 175 | 46.0s
# [038] MinNod=11, MaxNod=0, BasPhy=58, ElyPhy=0.0 | Loss = -0.6196 | n = 175 | 44.0s
# [039] MinNod=1, MaxNod=60, BasPhy=61, ElyPhy=0.0 | Loss = -0.5439 | n = 175 | 46.0s
# [040] MinNod=8, MaxNod=10, BasPhy=61, ElyPhy=0.8 | Loss = -0.7279 | n = 175 | 46.0s
#
# === Stage 3 ===
# [041] MinNod=9, MaxNod=0, BasPhy=62, ElyPhy=0.8 | Loss = -0.5718 | n = 172 | 46.0s
# [042] MinNod=8, MaxNod=16, BasPhy=60, ElyPhy=0.8 | Loss = -0.7168 | n = 175 | 44.0s
# [043] MinNod=11, MaxNod=0, BasPhy=52, ElyPhy=0.8 | Loss = -0.0078 | n = 173 | 46.0s
# [044] MinNod=9, MaxNod=12, BasPhy=61, ElyPhy=0.2 | Loss = -0.6193 | n = 175 | 47.0s
# [045] MinNod=15, MaxNod=1, BasPhy=59, ElyPhy=0.0 | Loss = -0.5503 | n = 179 | 45.0s
# [046] MinNod=0, MaxNod=60, BasPhy=76, ElyPhy=0.8 | Loss = -0.1684 | n = 177 | 45.0s
# [047] MinNod=5, MaxNod=60, BasPhy=53, ElyPhy=0.0 | Loss = -0.6410 | n = 177 | 45.0s
# [048] MinNod=8, MaxNod=17, BasPhy=62, ElyPhy=0.8 | Loss = -0.7305 | n = 175 | 45.0s
# [049] MinNod=0, MaxNod=60, BasPhy=52, ElyPhy=0.0 | Loss = -0.7055 | n = 174 | 44.0s
# [050] MinNod=30, MaxNod=60, BasPhy=100, ElyPhy=0.0 | Loss = 0.6745 | n = 187 | 46.0s
# Stopping: loss stagnation
#
# === Global optimum ===
# Loss: -0.7305
#
# === Local refinement ===
# [051] MinNod=8, MaxNod=17, BasPhy=62, ElyPhy=0.8 | Loss = -0.7305 | n = 175 | 46.0s
# [052] MinNod=8, MaxNod=16, BasPhy=66, ElyPhy=0.7 | Loss = -0.6542 | n = 175 | 45.0s
# [053] MinNod=8, MaxNod=15, BasPhy=62, ElyPhy=0.7 | Loss = -0.7280 | n = 175 | 47.0s
# [054] MinNod=7, MaxNod=17, BasPhy=57, ElyPhy=0.8 | Loss = -0.6324 | n = 174 | 47.0s
# [055] MinNod=8, MaxNod=15, BasPhy=68, ElyPhy=0.7 | Loss = -0.5031 | n = 177 | 45.0s
# [056] MinNod=8, MaxNod=15, BasPhy=56, ElyPhy=0.7 | Loss = -0.6872 | n = 175 | 46.0s
# [057] MinNod=8, MaxNod=15, BasPhy=68, ElyPhy=0.7 | Loss = -0.5031 | n = 177 | 48.0s
# [058] MinNod=7, MaxNod=17, BasPhy=61, ElyPhy=0.8 | Loss = -0.7313 | n = 175 | 45.0s
# [059] MinNod=8, MaxNod=18, BasPhy=64, ElyPhy=0.7 | Loss = -0.6934 | n = 175 | 46.0s
# [060] MinNod=7, MaxNod=18, BasPhy=63, ElyPhy=0.7 | Loss = -0.7165 | n = 175 | 46.0s
# [061] MinNod=9, MaxNod=18, BasPhy=61, ElyPhy=0.7 | Loss = -0.6282 | n = 177 | 47.0s
#
# === Final result ===
# Loss: -0.7313
# MinNod: 7
# MaxNod: 17
# BasPhy: 61
# ElyPhy: 0.75
#
# === Initial design: KelpieXT ===
# [001] MinNod=15, MaxNod=30, BasPhy=30, ElyPhy=0.3 | Loss = 0.9374 | n = 80 | 30.0s
# [002] MinNod=11, MaxNod=17, BasPhy=72, ElyPhy=0.2 | Loss = -0.0712 | n = 84 | 32.0s
# [003] MinNod=29, MaxNod=37, BasPhy=50, ElyPhy=0.1 | Loss = -0.2450 | n = 91 | 33.0s
# [004] MinNod=22, MaxNod=8, BasPhy=21, ElyPhy=0.2 | Loss = 1.0000 | n = 78 | 30.0s
# [005] MinNod=18, MaxNod=18, BasPhy=55, ElyPhy=0.3 | Loss = -0.5492 | n = 85 | 30.0s
# [006] MinNod=5, MaxNod=22, BasPhy=13, ElyPhy=0.2 | Loss = 1.0000 | n = 67 | 31.0s
# [007] MinNod=5, MaxNod=27, BasPhy=92, ElyPhy=0.6 | Loss = 0.5814 | n = 83 | 30.0s
# [008] MinNod=2, MaxNod=47, BasPhy=33, ElyPhy=0.2 | Loss = 0.3589 | n = 76 | 30.0s
# [009] MinNod=26, MaxNod=12, BasPhy=70, ElyPhy=0.2 | Loss = 0.0216 | n = 91 | 30.0s
# [010] MinNod=18, MaxNod=31, BasPhy=38, ElyPhy=0.4 | Loss = 0.3737 | n = 83 | 30.0s
# [011] MinNod=21, MaxNod=36, BasPhy=57, ElyPhy=0.1 | Loss = -0.4074 | n = 91 | 30.0s
# [012] MinNod=1, MaxNod=3, BasPhy=59, ElyPhy=0.6 | Loss = 0.1153 | n = 66 | 31.0s
# [013] MinNod=29, MaxNod=36, BasPhy=27, ElyPhy=0.1 | Loss = 0.9959 | n = 84 | 31.0s
# [014] MinNod=25, MaxNod=10, BasPhy=97, ElyPhy=0.8 | Loss = 0.6391 | n = 91 | 31.0s
# [015] MinNod=6, MaxNod=4, BasPhy=80, ElyPhy=0.6 | Loss = 0.3610 | n = 78 | 30.0s
# [016] MinNod=5, MaxNod=57, BasPhy=95, ElyPhy=0.2 | Loss = 0.5571 | n = 85 | 30.0s
# [017] MinNod=6, MaxNod=58, BasPhy=91, ElyPhy=0.0 | Loss = 0.4821 | n = 85 | 30.0s
# [018] MinNod=9, MaxNod=49, BasPhy=64, ElyPhy=0.6 | Loss = -0.5279 | n = 84 | 30.0s
# [019] MinNod=16, MaxNod=18, BasPhy=93, ElyPhy=0.6 | Loss = 0.4998 | n = 91 | 29.0s
# [020] MinNod=13, MaxNod=6, BasPhy=18, ElyPhy=0.6 | Loss = 1.0000 | n = 70 | 28.0s
#
# === Stage 1 ===
# [021] MinNod=16, MaxNod=60, BasPhy=58, ElyPhy=0.5 | Loss = -0.5211 | n = 87 | 30.0s
# [022] MinNod=0, MaxNod=22, BasPhy=56, ElyPhy=0.8 | Loss = -0.5398 | n = 75 | 29.0s
# [023] MinNod=30, MaxNod=60, BasPhy=65, ElyPhy=0.0 | Loss = -0.0390 | n = 91 | 29.0s
# [024] MinNod=0, MaxNod=52, BasPhy=56, ElyPhy=0.8 | Loss = -0.7391 | n = 79 | 29.0s
# [025] MinNod=3, MaxNod=60, BasPhy=50, ElyPhy=0.8 | Loss = -0.1987 | n = 80 | 29.0s
# [026] MinNod=15, MaxNod=46, BasPhy=58, ElyPhy=0.8 | Loss = -0.5529 | n = 85 | 30.0s
# [027] MinNod=0, MaxNod=51, BasPhy=59, ElyPhy=0.8 | Loss = -0.7871 | n = 79 | 29.0s
# [028] MinNod=0, MaxNod=58, BasPhy=60, ElyPhy=0.3 | Loss = -0.5097 | n = 79 | 28.0s
# [029] MinNod=0, MaxNod=56, BasPhy=60, ElyPhy=0.8 | Loss = -0.7897 | n = 79 | 29.0s
# [030] MinNod=0, MaxNod=23, BasPhy=55, ElyPhy=0.0 | Loss = -0.2278 | n = 75 | 29.0s
#
# === Stage 2 ===
# [031] MinNod=30, MaxNod=19, BasPhy=53, ElyPhy=0.8 | Loss = 0.0940 | n = 91 | 30.0s
# [032] MinNod=0, MaxNod=39, BasPhy=56, ElyPhy=0.6 | Loss = -0.6826 | n = 76 | 29.0s
# [033] MinNod=4, MaxNod=60, BasPhy=60, ElyPhy=0.8 | Loss = -0.7580 | n = 83 | 29.0s
# [034] MinNod=0, MaxNod=57, BasPhy=59, ElyPhy=0.7 | Loss = -0.7538 | n = 79 | 30.0s
# [035] MinNod=22, MaxNod=0, BasPhy=50, ElyPhy=0.0 | Loss = -0.5246 | n = 85 | 29.0s
# [036] MinNod=0, MaxNod=60, BasPhy=67, ElyPhy=0.8 | Loss = -0.5608 | n = 80 | 28.0s
# [037] MinNod=0, MaxNod=0, BasPhy=45, ElyPhy=0.8 | Loss = 0.9800 | n = 64 | 29.0s
# [038] MinNod=30, MaxNod=7, BasPhy=55, ElyPhy=0.0 | Loss = -0.2520 | n = 91 | 29.0s
# [039] MinNod=4, MaxNod=37, BasPhy=58, ElyPhy=0.8 | Loss = -0.7918 | n = 79 | 29.0s
# [040] MinNod=0, MaxNod=39, BasPhy=59, ElyPhy=0.8 | Loss = -0.7405 | n = 76 | 29.0s
#
# === Stage 3 ===
# [041] MinNod=4, MaxNod=40, BasPhy=57, ElyPhy=0.8 | Loss = -0.6046 | n = 80 | 27.0s
# [042] MinNod=0, MaxNod=41, BasPhy=61, ElyPhy=0.8 | Loss = -0.7255 | n = 76 | 29.0s
# [043] MinNod=0, MaxNod=33, BasPhy=59, ElyPhy=0.5 | Loss = -0.2717 | n = 76 | 27.0s
# [044] MinNod=0, MaxNod=60, BasPhy=51, ElyPhy=0.4 | Loss = -0.7844 | n = 79 | 29.0s
# [045] MinNod=0, MaxNod=42, BasPhy=51, ElyPhy=0.3 | Loss = -0.6911 | n = 76 | 27.0s
# [046] MinNod=0, MaxNod=60, BasPhy=52, ElyPhy=0.5 | Loss = -0.7959 | n = 79 | 29.0s
# [047] MinNod=0, MaxNod=60, BasPhy=53, ElyPhy=0.4 | Loss = -0.7668 | n = 79 | 28.0s
# [048] MinNod=0, MaxNod=0, BasPhy=48, ElyPhy=0.2 | Loss = -0.0673 | n = 64 | 29.0s
# [049] MinNod=0, MaxNod=60, BasPhy=49, ElyPhy=0.1 | Loss = -0.7571 | n = 79 | 28.0s
# [050] MinNod=6, MaxNod=60, BasPhy=52, ElyPhy=0.2 | Loss = -0.7168 | n = 83 | 29.0s
#
# === Stage 4 ===
# [051] MinNod=0, MaxNod=60, BasPhy=52, ElyPhy=0.2 | Loss = -0.7376 | n = 79 | 29.0s
# [052] MinNod=0, MaxNod=60, BasPhy=45, ElyPhy=0.0 | Loss = -0.5794 | n = 79 | 28.0s
# [053] MinNod=0, MaxNod=60, BasPhy=48, ElyPhy=0.2 | Loss = -0.7983 | n = 79 | 29.0s
# [054] MinNod=30, MaxNod=60, BasPhy=72, ElyPhy=0.8 | Loss = -0.0275 | n = 91 | 28.0s
# [055] MinNod=0, MaxNod=60, BasPhy=49, ElyPhy=0.2 | Loss = -0.7877 | n = 79 | 28.0s
# [056] MinNod=0, MaxNod=60, BasPhy=49, ElyPhy=0.3 | Loss = -0.7963 | n = 79 | 27.0s
# [057] MinNod=0, MaxNod=60, BasPhy=56, ElyPhy=0.6 | Loss = -0.7671 | n = 79 | 29.0s
# [058] MinNod=7, MaxNod=49, BasPhy=48, ElyPhy=0.2 | Loss = -0.6006 | n = 82 | 29.0s
# [059] MinNod=30, MaxNod=0, BasPhy=100, ElyPhy=0.0 | Loss = 0.6805 | n = 91 | 29.0s
# [060] MinNod=0, MaxNod=60, BasPhy=60, ElyPhy=0.8 | Loss = -0.7971 | n = 79 | 27.0s
#
# === Stage 5 ===
# [061] MinNod=0, MaxNod=60, BasPhy=50, ElyPhy=0.3 | Loss = -0.7856 | n = 79 | 29.0s
# [062] MinNod=0, MaxNod=60, BasPhy=71, ElyPhy=0.0 | Loss = -0.0221 | n = 80 | 28.0s
# [063] MinNod=30, MaxNod=60, BasPhy=10, ElyPhy=0.8 | Loss = 1.0000 | n = 76 | 28.0s
# [064] MinNod=0, MaxNod=60, BasPhy=52, ElyPhy=0.0 | Loss = -0.6683 | n = 79 | 28.0s
# [065] MinNod=0, MaxNod=60, BasPhy=54, ElyPhy=0.5 | Loss = -0.7680 | n = 79 | 27.0s
# [066] MinNod=0, MaxNod=60, BasPhy=60, ElyPhy=0.8 | Loss = -0.7971 | n = 79 | 29.0s
# [067] MinNod=0, MaxNod=60, BasPhy=50, ElyPhy=0.4 | Loss = -0.7956 | n = 79 | 29.0s
# [068] MinNod=0, MaxNod=32, BasPhy=59, ElyPhy=0.8 | Loss = -0.4452 | n = 76 | 29.0s
# [069] MinNod=30, MaxNod=38, BasPhy=62, ElyPhy=0.8 | Loss = -0.2635 | n = 91 | 30.0s
# [070] MinNod=0, MaxNod=45, BasPhy=57, ElyPhy=0.0 | Loss = -0.2161 | n = 77 | 27.0s
# Stopping: loss stagnation
#
# === Global optimum ===
# Loss: -0.7983
#
# === Local refinement ===
# [071] MinNod=0, MaxNod=60, BasPhy=48, ElyPhy=0.2 | Loss = -0.7983 | n = 79 | 27.0s
# [072] MinNod=1, MaxNod=55, BasPhy=51, ElyPhy=0.2 | Loss = -0.7592 | n = 79 | 29.0s
# [073] MinNod=0, MaxNod=55, BasPhy=48, ElyPhy=0.2 | Loss = -0.3188 | n = 79 | 28.0s
# [074] MinNod=0, MaxNod=58, BasPhy=44, ElyPhy=0.3 | Loss = -0.5187 | n = 77 | 28.0s
# [075] MinNod=1, MaxNod=54, BasPhy=53, ElyPhy=0.2 | Loss = -0.7138 | n = 79 | 29.0s
# [076] MinNod=0, MaxNod=54, BasPhy=44, ElyPhy=0.2 | Loss = -0.7661 | n = 76 | 28.0s
# [077] MinNod=0, MaxNod=54, BasPhy=53, ElyPhy=0.2 | Loss = -0.7016 | n = 79 | 28.0s
# [078] MinNod=0, MaxNod=58, BasPhy=47, ElyPhy=0.3 | Loss = -0.5968 | n = 79 | 29.0s
# [079] MinNod=0, MaxNod=59, BasPhy=50, ElyPhy=0.2 | Loss = -0.7741 | n = 79 | 29.0s
# [080] MinNod=0, MaxNod=60, BasPhy=49, ElyPhy=0.2 | Loss = -0.7877 | n = 79 | 28.0s
# [081] MinNod=0, MaxNod=60, BasPhy=52, ElyPhy=0.3 | Loss = -0.7530 | n = 79 | 29.0s
#
# === Final result ===
# Loss: -0.7983
# MinNod: 0
# MaxNod: 60
# BasPhy: 48
# ElyPhy: 0.25
#
# === Initial design: Nugget ===
# [001] MinNod=15, MaxNod=30, BasPhy=30, ElyPhy=0.3 | Loss = 0.9973 | n = 34 | 16.0s
# [002] MinNod=11, MaxNod=17, BasPhy=72, ElyPhy=0.2 | Loss = -0.3188 | n = 34 | 16.0s
# [003] MinNod=29, MaxNod=37, BasPhy=50, ElyPhy=0.1 | Loss = 0.2751 | n = 34 | 17.0s
# [004] MinNod=22, MaxNod=8, BasPhy=21, ElyPhy=0.2 | Loss = 1.0000 | n = 34 | 16.0s
# [005] MinNod=18, MaxNod=18, BasPhy=55, ElyPhy=0.3 | Loss = -0.4245 | n = 34 | 16.0s
# [006] MinNod=5, MaxNod=22, BasPhy=13, ElyPhy=0.2 | Loss = 1.0000 | n = 34 | 16.0s
# [007] MinNod=5, MaxNod=27, BasPhy=92, ElyPhy=0.6 | Loss = 0.0728 | n = 34 | 16.0s
# [008] MinNod=2, MaxNod=47, BasPhy=33, ElyPhy=0.2 | Loss = 0.9034 | n = 34 | 16.0s
# [009] MinNod=26, MaxNod=12, BasPhy=70, ElyPhy=0.2 | Loss = 0.6680 | n = 34 | 16.0s
# [010] MinNod=18, MaxNod=31, BasPhy=38, ElyPhy=0.4 | Loss = 0.7698 | n = 34 | 16.0s
# [011] MinNod=21, MaxNod=36, BasPhy=57, ElyPhy=0.1 | Loss = 0.0263 | n = 34 | 16.0s
# [012] MinNod=1, MaxNod=3, BasPhy=59, ElyPhy=0.6 | Loss = -0.1638 | n = 34 | 16.0s
# [013] MinNod=29, MaxNod=36, BasPhy=27, ElyPhy=0.1 | Loss = 0.9954 | n = 34 | 17.0s
# [014] MinNod=25, MaxNod=10, BasPhy=97, ElyPhy=0.8 | Loss = 0.9132 | n = 34 | 16.0s
# [015] MinNod=6, MaxNod=4, BasPhy=80, ElyPhy=0.6 | Loss = -0.3260 | n = 34 | 16.0s
# [016] MinNod=5, MaxNod=57, BasPhy=95, ElyPhy=0.2 | Loss = 0.4207 | n = 34 | 16.0s
# [017] MinNod=6, MaxNod=58, BasPhy=91, ElyPhy=0.0 | Loss = 0.3835 | n = 34 | 16.0s
# [018] MinNod=9, MaxNod=49, BasPhy=64, ElyPhy=0.6 | Loss = -0.5247 | n = 34 | 16.0s
# [019] MinNod=16, MaxNod=18, BasPhy=93, ElyPhy=0.6 | Loss = 0.7969 | n = 34 | 17.0s
# [020] MinNod=13, MaxNod=6, BasPhy=18, ElyPhy=0.6 | Loss = 1.0000 | n = 34 | 16.0s
#
# === Stage 1 ===
# [021] MinNod=4, MaxNod=12, BasPhy=71, ElyPhy=0.8 | Loss = -0.6954 | n = 34 | 16.0s
# [022] MinNod=0, MaxNod=56, BasPhy=74, ElyPhy=0.8 | Loss = -0.5451 | n = 34 | 17.0s
# [023] MinNod=6, MaxNod=41, BasPhy=70, ElyPhy=0.8 | Loss = -0.6006 | n = 34 | 16.0s
# [024] MinNod=2, MaxNod=16, BasPhy=70, ElyPhy=0.0 | Loss = -0.5285 | n = 34 | 16.0s
# [025] MinNod=4, MaxNod=0, BasPhy=71, ElyPhy=0.8 | Loss = -0.3322 | n = 34 | 16.0s
# [026] MinNod=0, MaxNod=52, BasPhy=76, ElyPhy=0.8 | Loss = -0.4716 | n = 34 | 15.0s
# [027] MinNod=9, MaxNod=1, BasPhy=62, ElyPhy=0.0 | Loss = -0.6630 | n = 34 | 16.0s
# [028] MinNod=10, MaxNod=60, BasPhy=60, ElyPhy=0.8 | Loss = -0.2250 | n = 34 | 16.0s
# [029] MinNod=9, MaxNod=19, BasPhy=62, ElyPhy=0.8 | Loss = -0.6377 | n = 34 | 15.0s
# [030] MinNod=12, MaxNod=0, BasPhy=58, ElyPhy=0.8 | Loss = -0.3182 | n = 34 | 16.0s
# Stopping: loss stagnation
#
# === Global optimum ===
# Loss: -0.6954
#
# === Local refinement ===
# [031] MinNod=4, MaxNod=12, BasPhy=71, ElyPhy=0.8 | Loss = -0.6954 | n = 34 | 16.0s
# [032] MinNod=5, MaxNod=11, BasPhy=75, ElyPhy=0.7 | Loss = -0.5259 | n = 34 | 16.0s
# [033] MinNod=4, MaxNod=11, BasPhy=70, ElyPhy=0.7 | Loss = -0.6860 | n = 34 | 16.0s
# [034] MinNod=4, MaxNod=13, BasPhy=64, ElyPhy=0.8 | Loss = -0.7320 | n = 34 | 16.0s
# [035] MinNod=5, MaxNod=11, BasPhy=78, ElyPhy=0.7 | Loss = -0.4258 | n = 34 | 17.0s
# [036] MinNod=5, MaxNod=11, BasPhy=64, ElyPhy=0.7 | Loss = -0.7684 | n = 34 | 16.0s
# [037] MinNod=4, MaxNod=11, BasPhy=77, ElyPhy=0.7 | Loss = -0.4515 | n = 34 | 16.0s
# [038] MinNod=4, MaxNod=13, BasPhy=69, ElyPhy=0.8 | Loss = -0.7524 | n = 34 | 16.0s
# [039] MinNod=4, MaxNod=13, BasPhy=73, ElyPhy=0.7 | Loss = -0.6038 | n = 34 | 16.0s
# [040] MinNod=4, MaxNod=14, BasPhy=72, ElyPhy=0.7 | Loss = -0.6431 | n = 34 | 16.0s
# [041] MinNod=5, MaxNod=13, BasPhy=67, ElyPhy=0.8 | Loss = -0.7809 | n = 34 | 16.0s
#
# === Final result ===
# Loss: -0.7809
# MinNod: 5
# MaxNod: 13
# BasPhy: 67
# ElyPhy: 0.75

# %%
fits.to_pickle("NodesFifthSetOfFits")

# %% [markdown]
# ## graphs

# %%
fits1 = pd.read_pickle("NodesfirstSetOfFits")
fits2 = pd.read_pickle("NodessecondSetOfFits")
fits3 = pd.read_pickle("NodesthirdSetOfFits")
fits4 = pd.read_pickle("NodesForthSetOfFits")
fits5 = pd.read_pickle("NodesFifthSetOfFits")

# %%
fits5["best_x"]
# Out:
# Ace            [10, 1, 54, 0.0]
# Blitz          [8, 1, 64, 0.55]
# Bolt          [12, 0, 65, 0.75]
# Digger         [0, 34, 46, 0.0]
# Greenfield    [4, 33, 69, 0.75]
# HallmarkXT     [14, 0, 55, 0.0]
# Jumbo2        [7, 17, 61, 0.75]
# KelpieXT      [0, 60, 48, 0.25]
# Nugget        [5, 13, 67, 0.75]
# Name: best_x, dtype: object

# %% [markdown]
# ### Evolution of fitting

# %%
def graphFitEvolve(fits):
    graph = plt.figure(figsize=(9,15))
    pos = 1
    for c in CULTIVAR_FILE_DICT.keys():
        ax = graph.add_subplot(7,4,pos)
        fpos = 0
        for fit in fits:
            try:
                fcol = Colors[fpos+1]
                STORE = fit.loc[c,"STORE"]
                nse = -fit.loc[c,"best_y"]
                df = STORE.to_dataframe()
                df.loss.plot(color = fcol)
                plt.text(0.98,0.88-0.1*fpos,f"{nse:.2g}",horizontalalignment='right',
                 verticalalignment='top', transform=ax.transAxes, color = fcol)
            except:
                do = 'nothing'
            fpos+=1
        plt.text(0.98,0.98,c,horizontalalignment='right',
                 verticalalignment='top', transform=ax.transAxes)

        plt.ylim(-1.05,1.05)
        plt.xlim(0,90)
        pos+=1

graphFitEvolve([fits1,fits2,fits3,fits4,fits5])

# %% [markdown]
# ### obs vs pred scaled

# %%
def graphObsPred(fits):
    graph = plt.figure(figsize=(9,15))
    pos = 1
    for c in CULTIVAR_FILE_DICT.keys():
        ax = graph.add_subplot(7,4,pos)
        fpos = 0
        for fit in fits:
            try:
                fcol = Colors[fpos +1]
                STORE = fit.loc[c,"STORE"]
                nse = -fit.loc[c,"best_y"]
                df = STORE.to_dataframe()
            
                # Find the best iteration (minimum loss)
                best_idx = df["loss"].idxmin()
                best_row = df.loc[best_idx]
                best_iter = best_row["iteration"]
                    
                # Plot Obs vs Pred for the best iteration
                plt.plot(best_row["obs"], best_row["pred"], "o", alpha=0.6, color = fcol)
                plt.text(0.02,0.88-0.1*fpos,f"{nse:.2g}",horizontalalignment='left',
                        verticalalignment='top', transform=ax.transAxes, color = fcol)
            except:
                do = 'nothing'
            fpos+=1
        plt.plot([0,1],[0,1], "k--")
        plt.xlabel("Observed")
        plt.ylabel("Predicted")
        #plt.title(f"Best iteration {best_iter}, NSE={-best_row['loss']:.3f}")
        #plt.show
        plt.text(0.02,0.98,c,horizontalalignment='left',
                 verticalalignment='top', transform=ax.transAxes)
        plt.ylim(-0.05,1.05)
        plt.xlim(-0.05,1.05)
        pos+=1

graphObsPred([fits1,fits2,fits3,fits4])

# %% [markdown]
# ### parameter ranges

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.colors import Normalize


def plot_parameter_bars(
    fits_df,
    param_config,
    sort=True,
    colour_by_loss=True,
    figsize=(10, 4)
):
    """
    Plot bar charts of fitted parameter values across cultivars with bounds.

    Parameters
    ----------
    fits_df : DataFrame
        Must contain 'best_x' and 'best_y', index = cultivars
    param_config : list of dict
        Defines parameter names, bounds, etc.
    sort : bool
        Sort cultivars by parameter value
    colour_by_loss : bool
        Colour bars by fit quality (best_y)
    """

    df = fits_df.copy()

    # -------------------------
    # Expand best_x
    # -------------------------
    param_cols = pd.DataFrame(df["best_x"].tolist(), index=df.index)

    param_names = [p["short_name"] for p in param_config]
    param_cols.columns = param_names

    df_params = pd.concat([df, param_cols], axis=1)

    # Ensure best_y is numeric
    df_params["best_y"] = pd.to_numeric(df_params["best_y"], errors="coerce")

    # -------------------------
    # Plot each parameter
    # -------------------------
    for i, p in enumerate(param_config):

        pname = p["short_name"]
        low, high = p["bounds"]

        plt.figure(figsize=figsize)

        plot_df = df_params.copy()

        if sort:
            plot_df = plot_df.sort_values(pname)

        values = plot_df[pname]

        ax = plt.gca()

        # -------------------------
        # Colour by loss
        # -------------------------
        if colour_by_loss:

            loss = plot_df["best_y"].fillna(plot_df["best_y"].max()).values.astype(float)
            
            vmin = np.min(loss)
            vmax = np.max(loss)
            
            if np.isclose(vmin, vmax):
                colors = ["steelblue"] * len(loss)
            else:
                norm = Normalize(vmin=vmin, vmax=vmax)
                normed = norm(loss)
            
                # ✅ invert so better fits (lower loss) = darker
                normed = 1 - normed
            
                colors = plt.cm.viridis(normed)
            
                sm = plt.cm.ScalarMappable(cmap="viridis", norm=norm)
                sm.set_array([])
            
                ax = plt.gca()
                cbar = plt.colorbar(sm, ax=ax)
                cbar.set_label("Fit quality (best_y)")
            
            plt.bar(plot_df.index, values, color=colors)
        else:
            plt.bar(plot_df.index, values)

        # -------------------------
        # Bounds lines
        # -------------------------
        ax.axhline(low, linestyle="--", color="red", linewidth=1)
        ax.axhline(high, linestyle="--", color="red", linewidth=1)

        # -------------------------
        # Titles and formatting
        # -------------------------
        ax.set_title(f"{pname} across cultivars")
        ax.set_ylabel("Value")

        plt.xticks(rotation=45, ha="right")

        # Only show legend once (optional)
        ax.legend(loc="upper right")

        plt.tight_layout()
        plt.show()


plot_parameter_bars(fits4, param_config)
# Out:
# C:\Users\Cflhxb\AppData\Local\Temp\ipykernel_21364\2427721035.py:110: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend(loc="upper right")

# %% [markdown]
# ### fit surfaces

# %%
from skopt.plots import plot_objective
from skopt.utils import create_result
opt = fits4.loc["HallmarkXT","opt"]
res = create_result(
    Xi=opt.Xi,
    yi=np.array(opt.yi),
    space=opt.space,
    specs=None,
    models=opt.models
)

plot_objective(res)
# Out:
# <Axes: >

# %% [markdown]
# ## Inject fitted parameters to lentil.json

# %%
import json


def update_apsimx_cultivars(
    crop_json_path,
    fits_df,
    param_config
):

    with open(crop_json_path, "r") as f:
        data = json.load(f)

    # -------------------------
    # Find Cultivars node
    # -------------------------
    def find_cultivars_node(node):
        if isinstance(node, dict):
            if node.get("Name") == "Cultivars":
                return node
            for child in node.get("Children", []):
                result = find_cultivars_node(child)
                if result:
                    return result
        elif isinstance(node, list):
            for item in node:
                result = find_cultivars_node(item)
                if result:
                    return result
        return None

    cultivars_node = find_cultivars_node(data)

    if cultivars_node is None:
        raise RuntimeError("Could not find 'Cultivars' node in APSIM file")

    # -------------------------
    # Update cultivars
    # -------------------------
    for cultivar_node in cultivars_node.get("Children", []):

        cultivar_name = cultivar_node.get("Name")

        if cultivar_name not in fits_df.index:
            continue

        best_x = fits_df.loc[cultivar_name, "best_x"]

        # -------------------------
        # Existing commands → dict
        # -------------------------
        existing_cmds = cultivar_node.get("Command", [])

        cmd_dict = {}

        for cmd in existing_cmds:
            if "=" in cmd:
                key = cmd.split("=")[0].strip()
                cmd_dict[key] = cmd  # keep full string
            else:
                # preserve unknown format lines
                cmd_dict[cmd] = cmd

        # -------------------------
        # New commands (overwrite or add)
        # -------------------------
        for val, p in zip(best_x, param_config):

            step = p.get("step")
            val_str = format_value(val, step)

            key = p["name"]
            cmd = f"{key} = {val_str}"

            cmd_dict[key] = cmd  # ✅ overwrite or add

        # -------------------------
        # Rebuild command list
        # -------------------------
        cultivar_node["Command"] = list(cmd_dict.values())

        print(f"Updated cultivar: {cultivar_name}")

    # -------------------------
    # Save
    # -------------------------
    with open(crop_json_path, "w") as f:
        json.dump(data, f, indent=2)

    print(f"\nUpdated APSIM file written to:\n{crop_json_path}")

# %%
update_apsimx_cultivars(
    crop_json_path="C:\GitHubRepos\ApsimX\Models\Resources\Lentil.json",
    fits_df=fits5,
    param_config=param_config
)
# Out:
# Updated cultivar: Ace
# Updated cultivar: Blitz
# Updated cultivar: Bolt
# Updated cultivar: Greenfield
# Updated cultivar: HallmarkXT
# Updated cultivar: Jumbo2
# Updated cultivar: KelpieXT
# Updated cultivar: Nugget
#
# Updated APSIM file written to:
# C:\GitHubRepos\ApsimX\Models\Resources\Lentil.json

# %%
param_config = [
    {
        "name": "[Phenology].MinFloralNodes.FixedValue",
        "short_name": "MinNod",
        "bounds": (0, 40),
        "step": 1,
        "initial": 15
    },
    {
        "name": "[Phenology].PpFloralNodes.FixedValue",
        "short_name": "MaxNod",
        "bounds": (0, 60),
        "step": 1,
        "initial": 30
    },
    {
        "name": "[Leaf].BasePhyllochron.FixedValue",
        "short_name": "BasPhy",
        "bounds": (10, 100),
        "step": 1,
        "initial": 30
    }
]

# %%
fits3['best_x']
# Out:
# Ace           [0, 39, 55]
# Blitz         [10, 0, 55]
# Bolt          [12, 0, 52]
# Greenfield    [13, 1, 59]
# HallmarkXT    [14, 0, 54]
# Jumbo2        [13, 1, 48]
# KelpieXT      [8, 39, 45]
# Nugget        [0, 45, 52]
# Name: best_x, dtype: object
