# %%
import datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
# %matplotlib inline

# %% [markdown]
# ## Make a list of observed files

# %%
SubStoreFilePaths = []
mydir = r'C:\Users\cflhxb\Dropbox\APSIMPotato\Observed\SubStorValidationData\experiments'
for file in os.listdir(mydir):
    if file.endswith('.xlsx'):
        SubStoreFilePaths.append(os.path.join(mydir, file))

# %% [markdown]
# ## Make a list of data frames to work through

# %%
SubStoreFiles = []
for ObsTable in SubStoreFilePaths:
    SubStoreFiles.append(pd.read_excel(ObsTable))

# %%
def IsMetaDataRow(RowVal):
    if isinstance(RowVal, basestring):
        if 'Metadata' in RowVal:
            return True
        else:
            return False
    else: 
        return False

def IsTimeSeriesRow(RowVal):
    if isinstance(RowVal, basestring):
        if 'Time' in RowVal:
            return True
        else:
            return False
    else: 
        return False

# %% [markdown]
# ## Go through each data file and put the experiment name and treatments into a index frame

# %%
TreatList = []
for ObsTable in SubStoreFiles:
    MetaDataMask = [IsMetaDataRow(x) for x in ObsTable.iloc[:,0]]
    FirstTreatRowPos = ObsTable.iloc[MetaDataMask].index[0] + 5
    TreatRow = FirstTreatRowPos
    while isinstance(ObsTable.iloc[TreatRow,0], int):
        TreatNumber = ObsTable.iloc[TreatRow,0]
        ExpName = str(ObsTable.iloc[TreatRow][3] )
        TreatName = ExpName + str(ObsTable.iloc[TreatRow][5])
        TreatName = TreatName.replace(' ','')
        TreatName = TreatName.replace('=','')
        TreatName = TreatName.replace('%','')
        TreatList.append([ExpName,TreatNumber,TreatName])
        TreatRow +=1
TreatmentIndex = pd.DataFrame(data=TreatList, 
                          columns = ['ExpName','TreatNumber','TreatName'])
TreatmentIndex.set_index('TreatName',inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-7c8828f3bb9b> in <module>()
#       1 TreatList = []
#       2 for ObsTable in SubStoreFiles:
# ----> 3     MetaDataMask = [IsMetaDataRow(x) for x in ObsTable.iloc[:,0]]
#       4     FirstTreatRowPos = ObsTable.iloc[MetaDataMask].index[0] + 5
#       5     TreatRow = FirstTreatRowPos
#
# <ipython-input-7-7c8828f3bb9b> in <listcomp>(.0)
#       1 TreatList = []
#       2 for ObsTable in SubStoreFiles:
# ----> 3     MetaDataMask = [IsMetaDataRow(x) for x in ObsTable.iloc[:,0]]
#       4     FirstTreatRowPos = ObsTable.iloc[MetaDataMask].index[0] + 5
#       5     TreatRow = FirstTreatRowPos
#
# <ipython-input-5-793468a92293> in IsMetaDataRow(RowVal)
#       1 def IsMetaDataRow(RowVal):
# ----> 2     if isinstance(RowVal, basestring):
#       3         if 'Metadata' in RowVal:
#       4             return True
#       5         else:
#
# NameError: name 'basestring' is not defined

# %%
TreatmentIndex
# Out:
#                                ExpName  TreatNumber
# TreatName
# AMNG9901VariedadCapiro        AMNG9901            1
# AUCB7001Radiation100Deficit2  AUCB7001            1
# AUCB7001Radiation79Deficit2   AUCB7001            2
# AUCB7001Radiation66Deficit2   AUCB7001            3
# AUHU9601N_Fertilizer90kg/ha   AUHU9601            2
# AUHU9801N_Fertilizer150kg/ha  AUHU9801            1
# CHBE9801OTC_CF_CF_98          CHBE9801            1
# CHBE9801OTC_NF_NF_98          CHBE9801            2
# CHBE9801OTC_NF++_NF_98        CHBE9801            3
# CHBE9801AA_98                 CHBE9801            6
# CHBE9801OTC_CF_CF_99          CHBE9801            7
# CHBE9801OTC_NF_NF_99          CHBE9801            8
# CHBE9801OTC_NF++_NF_99        CHBE9801            9
# CHBE9801AA_99                 CHBE9801           12
# CHFI9801OTC_AA_AA_98          CHFI9801            1
# CHFI9801OTC_NF_NF_98          CHFI9801            2
# CHFI9801OTC_NF+_NF_99         CHFI9801            3
# CHFI9801OTC_AA_AA_99          CHFI9801            4
# CHFI9801OTC_NF_NF_99          CHFI9801            5
# CHGR9801OTC_NF_CF_98          CHGR9801            1
# CHGR9801OTC_NF+_CF_98         CHGR9801            2
# CHGR9801OTC_NF++_CF_98        CHGR9801            3
# CHGR9801FACE_FACE_CF_98       CHGR9801            8
# CHGR9801FACE_FACE+_CF_98      CHGR9801            9
# CHGR9801OTC_NF_CF_99          CHGR9801           10
# CHGR9801OTC_NF+_CF_99         CHGR9801           11
# CHGR9801OTC_NF++_CF_99        CHGR9801           12
# CHGR9801FACE_FACE_CF_99       CHGR9801           17
# CHGR9801FACE_FACE+_CF_99      CHGR9801           18
# CHIE9801OTC_NF_NF_98          CHIE9801            1
# ...                                ...          ...
# PULU0801I20N135               PULU0801           22
# PULU0801I20N180               PULU0801           23
# PULU0801I20N225               PULU0801           24
# SCDU8401MarPip_N0_84          SCDU8401            1
# SCDU8401MarPip_N240_84        SCDU8401            2
# SCDU8401MarPip_N0_85          SCDU8401            3
# SCDU8401MarPip_N240_85        SCDU8401            4
# SCDU8401MarPip_wet_86         SCDU8401            5
# SCDU8401MarPip_dry_86         SCDU8401            6
# SCDU8401MarPip_wet_87         SCDU8401            7
# SCDU8401MarPip_dry_87         SCDU8401            8
# SFUF1001Pivot19(2010)         SFUF1001            1
# SFUF1001Pivot12(2011)         SFUF1001            2
# SFUF1001Pivot17(2011)         SFUF1001            3
# SFUF1001Pivot10(2012)         SFUF1001            4
# SFUF1001Pivot18(2012)         SFUF1001            5
# SFUF1001Pivot12(2013)         SFUF1001            6
# UFHA10012011_F1_3             UFHA1001           19
# UFHA10012011_F1_5             UFHA1001           21
# UFHA10012011_F2_3             UFHA1001           27
# UFHA10012011_F2_5             UFHA1001           29
# UFHA10012011_F3_3             UFHA1001           35
# UFHA10012011_F3_5             UFHA1001           37
# UFSF0101North_Farmer_2001     UFSF0101            1
# UFSF0101South_New_2001        UFSF0101            2
# UFSF0101North_Farmer_2002     UFSF0101            3
# UFSF0101South_New_2002        UFSF0101            4
# UFSF0101All_2003              UFSF0101            5
# USBE0301B                     USBE0301            1
# USBE0301D                     USBE0301            2
#
# [222 rows x 2 columns]

# %% [markdown]
# ## Find the column headers for observed data and and add them into a column index

# %%
ColumnHeaders = ['SimulationName','Clock.Today','TreatmentNumber']
for ObsTable in SubStoreFiles:
    TimeSeriesMask = [IsTimeSeriesRow(x) for x in ObsTable.iloc[:,0]]
    ColumnIndexRow = ObsTable.iloc[TimeSeriesMask].index[0] + 3
    ObsTable.iloc[ColumnIndexRow,0] = u'TreatmentNumber'
    ObsTable.iloc[ColumnIndexRow,1] = u'Clock.Today'
    member = 0
    for x in ObsTable.iloc[ColumnIndexRow].values:
        if isinstance(x, basestring):
            ObsTable.iloc[ColumnIndexRow,member] = x.replace('!','')
        member +=1
    member = 0
    for x in ObsTable.iloc[ColumnIndexRow].values:
        if isinstance(x, basestring):
            ObsTable.iloc[ColumnIndexRow,member] = x.replace('Ad','AD')
        member +=1
    member = 0
    for x in ObsTable.iloc[ColumnIndexRow].values:
        if isinstance(x, basestring):
            ObsTable.iloc[ColumnIndexRow,member] = x.replace('TUNA','PNAD')
        member +=1
    member = 0
    for x in ObsTable.iloc[ColumnIndexRow].values:
        if isinstance(x, basestring):
            ObsTable.iloc[ColumnIndexRow,member] = x.replace('UN%H','UN%D')
        member +=1
    member = 0
    for x in ObsTable.iloc[ColumnIndexRow].values:
        if isinstance(x, basestring):
            ObsTable.iloc[ColumnIndexRow,member] = x.replace('UYAFH','UYAD')
        member +=1
    member = 0
    for x in ObsTable.iloc[ColumnIndexRow].values:
        if isinstance(x, basestring):
            ObsTable.iloc[ColumnIndexRow,member] = x.replace('UYFAD','UYAD')
        member +=1
    
    ObsList = ObsTable.iloc[ColumnIndexRow,1:].dropna().values
    ObsList = [str(ObsList[x]) for x in range(len(ObsList))]
    #ObsList = [ObsList[x].replace('!','') for x in range(len(ObsList))]
    
    ColumnHeaders = list(set().union(ColumnHeaders, ObsList))

# %%
ColumnHeaders.append('Experiment')
ColumnHeaders
# Out:
# ['NUPC',
#  'SN%D',
#  'SW3D',
#  'NH1D',
#  'NI1D',
#  'SW1D',
#  'NI3D',
#  'CWAD',
#  'CYAD',
#  'SWAD',
#  'RN%D',
#  'SW2D',
#  'DWAD',
#  'LWAD',
#  'UNAD',
#  'SW4D',
#  'RNAD',
#  'CNAD',
#  'LNAD',
#  'TWAD',
#  'NH4D',
#  'SimulationName',
#  'CN%D',
#  'NI2D',
#  'HIAD',
#  'NI4D',
#  'Clock.Today',
#  'UYAD',
#  'UN%D',
#  'RWAD',
#  'LN%D',
#  'TreatmentNumber',
#  'NH2D',
#  'UWAD',
#  'SNAD',
#  'PNAD',
#  'LAID',
#  'TDWA',
#  'NH3D',
#  'Experiment']

# %% [markdown]
# ## Make an empty dataframe to merge all of the data into

# %%
ObsData = pd.DataFrame(columns = ColumnHeaders)
HeaderInfo = pd.DataFrame(columns = ['Definitions','Units','Code'])

# %% [markdown]
# ## Step through each datatable and put the data into the merged table

# %%
Count = 0
CleanTabs = []
for ObsTable in SubStoreFiles:
    #Make a data frame with the treatment indexs for this table
    MetaDataMask = [IsMetaDataRow(x) for x in ObsTable.iloc[:,0]]
    FirstTreatRowPos = ObsTable.iloc[MetaDataMask].index[0] + 5
    TreatRow = FirstTreatRowPos
    TreatNumbers = []
    TreatNames = []
    while isinstance(ObsTable.iloc[TreatRow,0], int):
        TreatName = str(ObsTable.iloc[TreatRow,3] ) + str(ObsTable.iloc[TreatRow,5])
        TreatName = TreatName.replace(' ','')
        TreatName = TreatName.replace('=','')
        TreatName = TreatName.replace('%','')
        TreatNames.append([TreatName])
        TreatNumbers.append(ObsTable.iloc[TreatRow,0])
        TreatRow +=1
    TreatIndex = pd.DataFrame(index = TreatNumbers,
                              data=TreatNames,
                              columns=['TreatmentName'])
    #Find the observed data for this table
    TimeSeriesMask = [IsTimeSeriesRow(x) for x in ObsTable.iloc[:,0]]
    ColumnIndexRow = ObsTable.iloc[TimeSeriesMask].index[0] + 3
    FirstObsRowPos = ObsTable.iloc[TimeSeriesMask].index[0] + 4
          
    #Make a Dataframe with the observed data for this experiment
    Columns = ObsTable.iloc[ColumnIndexRow].values
    CleanTable = pd.DataFrame(data = ObsTable.iloc[FirstObsRowPos:].values,
                             columns = Columns)
    CleanTable.dropna(axis = 0, how='all',inplace=True)
    CleanTable.dropna(axis = 1, how='all',inplace=True)
    CleanTable.ix[:,'SimulationName'] = [TreatIndex.ix[x,'TreatmentName'] for x in CleanTable.ix[:,'TreatmentNumber'].values]
    CleanTabs.append(CleanTable)
    Headers = pd.DataFrame(data = ObsTable.iloc[FirstObsRowPos-3:FirstObsRowPos].transpose().values,
                          columns = ['Definitions','Units','Code'] )
    HeaderInfo = HeaderInfo.append(Headers,ignore_index=True)
    Count +=1

# %%
for Tab in CleanTabs:
    ObsData = ObsData.append(Tab.ix[:,ColumnHeaders])

# %%
ObsData.ix[:,'Clock.Today']
# Out:
# 0              1999-06-04
# 1              1999-06-17
# 2              1999-06-30
# 3              1999-07-13
# 4              1999-07-26
# 5              1999-08-08
# 6              1999-08-22
# 7              1999-09-05
# 8              1999-09-19
# 0     1970-10-19 00:00:00
# 1     1970-10-26 00:00:00
# 2     1970-11-02 00:00:00
# 3     1970-11-09 00:00:00
# 4     1970-11-16 00:00:00
# 5     1970-11-23 00:00:00
# 6     1970-11-30 00:00:00
# 7     1970-12-07 00:00:00
# 8     1970-12-14 00:00:00
# 9     1970-12-22 00:00:00
# 10    1970-10-19 00:00:00
# 11    1970-10-26 00:00:00
# 12    1970-11-02 00:00:00
# 13    1970-11-09 00:00:00
# 14    1970-11-16 00:00:00
# 15    1970-11-23 00:00:00
# 16    1970-11-30 00:00:00
# 17    1970-12-07 00:00:00
# 18    1970-12-14 00:00:00
# 19    1970-12-22 00:00:00
# 20    1970-10-19 00:00:00
#              ...
# 55    2003-05-06 00:00:00
# 56    2003-01-23 00:00:00
# 57    2003-01-28 00:00:00
# 58    2003-02-04 00:00:00
# 59    2003-02-18 00:00:00
# 60    2003-02-25 00:00:00
# 61    2003-03-04 00:00:00
# 62    2003-03-11 00:00:00
# 63    2003-03-18 00:00:00
# 64    2003-03-25 00:00:00
# 65    2003-04-01 00:00:00
# 66    2003-04-08 00:00:00
# 67    2003-04-15 00:00:00
# 68    2003-04-22 00:00:00
# 69    2003-04-29 00:00:00
# 70    2003-05-06 00:00:00
# 71    2003-05-13 00:00:00
# 72    2003-05-20 00:00:00
# 0     2003-05-22 00:00:00
# 1     2003-05-30 00:00:00
# 2     2003-06-12 00:00:00
# 3     2003-07-01 00:00:00
# 4     2003-07-22 00:00:00
# 5     2003-08-19 00:00:00
# 6     2003-05-22 00:00:00
# 7     2003-05-30 00:00:00
# 8     2003-06-12 00:00:00
# 9     2003-07-01 00:00:00
# 10    2003-07-22 00:00:00
# 11    2003-08-19 00:00:00
# Name: Clock.Today, dtype: object

# %%
SubStoreObservations = ObsData
SubStoreObservations.ix[:,'Clock.Today'] = pd.to_datetime(SubStoreObservations.ix[:,'Clock.Today'])
SubStoreObservations.ix[:,'Experiment'] = [TreatmentIndex.ix[x,'ExpName'] for x in SubStoreObservations.ix[:,'TreatmentNumber']]
SubStoreObservations.drop('HIAD',inplace=True,axis=1)

# %%
ColTranslation = [ 'Potato.AboveGroundLive.NConc',
 'Potato.AboveGroundLive.N',
 'Potato.AboveGroundLive.Wt',
 'Potato.AboveGroundLive.FWt',
 'Clock.Today',
 'Potato.AboveGroundDead.Wt',
 'Experiment',                 
 'Potato.Leaf.LAI',
 'Potato.Leaf.Live.NConc',
 'Potato.Leaf.Live.N',
 'Potato.Leaf.Live.Wt',
 'Soil.SoilNitrogen.NH4ppm(1)',
 'Soil.SoilNitrogen.NH4ppm(2)',
 'Soil.SoilNitrogen.NH4ppm(3)',
 'Soil.SoilNitrogen.NH4ppm(4)',
 'Soil.SoilNitrogen.NO3ppm(1)',
 'Soil.SoilNitrogen.NO3ppm(2)',
 'Soil.SoilNitrogen.NO3ppm(3)',
 'Soil.SoilNitrogen.NO3ppm(4)',
 'Potato.Total.N',
 'Potato.TotalLive.N',
 'Potato.Root.NConc',
 'Potato.Root.N',
 'Potato.Root.Wt',
 'Potato.Stem.NConc',
 'Potato.Stem.N',
 'Soil.SoilWater.SW(1)',
 'Soil.SoilWater.SW(2)',
 'Soil.SoilWater.SW(3)',
 'Soil.SoilWater.SW(4)',
 'Potato.Stem.Wt',
 'SimulationName',
 'TDWA',
 'TWAD',
 'TreatmentNumber',
 'Potato.Tuber.Live.NConc',
 'Potato.Tuber.N',
 'Potato.Tuber.Wt',
 'Potato.Tuber.LiveFWt']

# %%
HeaderInfo = HeaderInfo.dropna()
HeaderInfo = HeaderInfo.drop_duplicates(subset='Code')
HeaderInfo.ix[1200,:] = ['Experiment','',u'Experiment']
HeaderInfo.ix[1201,:] = ['SimulationName','',u'SimulationName']
HeaderInfo.sort_values(by='Code',inplace=True)
HeaderInfo.ix[:,'VariableName'] = ColTranslation

# %%
HeaderInfo
# Out:
#                         Definitions         Units             Code  \
# 49               Tops (ie.canopy) N             %             CN%D
# 50                         Tops N           kg/ha             CNAD
# 10      Tops(leaf+stem) dry weight     kg [dm]/ha             CWAD
# 64    Tops(leaf+stem) fresh weight     Mg [fm]/ha             CYAD
# 1                  Observation date    yyyy-mm-dd      Clock.Today
# 7          Dead_material_dry_weight   kg [dm]/ha              DWAD
# 1200                     Experiment                     Experiment
# 8                   leaf area index         m2/m2             LAID
# 218                          Leaf N             %             LN%D
# 46                          Leaf N          kg/ha             LNAD
# 6                   Leaf dry weight    kg [dm]/ha             LWAD
# 229                NH4 soil layer 1  ug[N]/g soil             NH1D
# 230                NH4 soil layer 2  ug[N]/g soil             NH2D
# 231                NH4 soil layer 3  ug[N]/g soil             NH3D
# 232                NH4 soil layer 4  ug[N]/g soil             NH4D
# 225                NO3 soil layer 1  ug[N]/g soil             NI1D
# 226                NO3 soil layer 2  ug[N]/g soil             NI2D
# 227                NO3 soil layer 3  ug[N]/g soil             NI3D
# 228                NO3 soil layer 4  ug[N]/g soil             NI4D
# 791                        N_uptake         kg/ha             NUPC
# 51                        Plant N           kg/ha             PNAD
# 94                           Root N             %             RN%D
# 91                         Root N           kg/ha             RNAD
# 9                   Root_dry_weight         kg/ha             RWAD
# 219                          Stem N             %             SN%D
# 48                          Stem N          kg/ha             SNAD
# 233         soil water soil layer 1       cm3/cm3             SW1D
# 234         soil water soil layer 2       cm3/cm3             SW2D
# 235         soil water soil layer 3       cm3/cm3             SW3D
# 236         soil water soil layer 4       cm3/cm3             SW4D
# 5                   Stem_dry_weight    kg [dm]/ha             SWAD
# 1201                 SimulationName                 SimulationName
# 86          Tops_roots_storage_d_wt         kg/ha             TDWA
# 2           Tops_roots_storage_d_wt         kg/ha             TWAD
# 0                     ! Definitions       ! Units  TreatmentNumber
# 92              Tuber N at harvest              %             UN%D
# 47                         Tuber N          kg/ha             UNAD
# 4               Tuber dry weight      kg [dm]/ha              UWAD
# 3                Tuber fresh weight    Mg [fw]/ha             UYAD
#
#                       VariableName
# 49    Potato.AboveGroundLive.NConc
# 50        Potato.AboveGroundLive.N
# 10       Potato.AboveGroundLive.Wt
# 64      Potato.AboveGroundLive.FWt
# 1                      Clock.Today
# 7        Potato.AboveGroundDead.Wt
# 1200                    Experiment
# 8                  Potato.Leaf.LAI
# 218         Potato.Leaf.Live.NConc
# 46              Potato.Leaf.Live.N
# 6              Potato.Leaf.Live.Wt
# 229    Soil.SoilNitrogen.NH4ppm(1)
# 230    Soil.SoilNitrogen.NH4ppm(2)
# 231    Soil.SoilNitrogen.NH4ppm(3)
# 232    Soil.SoilNitrogen.NH4ppm(4)
# 225    Soil.SoilNitrogen.NO3ppm(1)
# 226    Soil.SoilNitrogen.NO3ppm(2)
# 227    Soil.SoilNitrogen.NO3ppm(3)
# 228    Soil.SoilNitrogen.NO3ppm(4)
# 791                 Potato.Total.N
# 51              Potato.TotalLive.N
# 94               Potato.Root.NConc
# 91                   Potato.Root.N
# 9                   Potato.Root.Wt
# 219              Potato.Stem.NConc
# 48                   Potato.Stem.N
# 233           Soil.SoilWater.SW(1)
# 234           Soil.SoilWater.SW(2)
# 235           Soil.SoilWater.SW(3)
# 236           Soil.SoilWater.SW(4)
# 5                   Potato.Stem.Wt
# 1201                SimulationName
# 86                            TDWA
# 2                             TWAD
# 0                  TreatmentNumber
# 92         Potato.Tuber.Live.NConc
# 47                  Potato.Tuber.N
# 4                  Potato.Tuber.Wt
# 3             Potato.Tuber.LiveFWt

# %%
SubStoreObservations.sort_index(axis=1,inplace=True)
SubStoreObservations.columns = HeaderInfo.ix[:,'VariableName'].values
SubStoreObservations.set_index(['SimulationName','Clock.Today'],inplace=True)
SubStoreObservations.ix[:,'PlantandHarvest.Script.FinalTag'] = ''
Sorted = SubStoreObservations.sort_index()

# %%
Simulations = SubStoreObservations.index.get_level_values(0)
for Sim in Simulations:
    Finalkey = (Sim,SubStoreObservations.ix[Sim].ix[-1:,:].index[0])
    SubStoreObservations.ix[Finalkey,'PlantandHarvest.Script.FinalTag'] = 'yield'

# %%
SubStoreObservations.to_excel('C:\Users\cflhxb\Dropbox\APSIMPotato\Observed\SubStoreObservationsTest.xlsx',
                              merge_cells=False)
