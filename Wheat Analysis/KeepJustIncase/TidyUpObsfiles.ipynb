# %%
import pandas as pd
import glob
import os

# Specify the directory containing your CSV files
directory_path = 'C:/GitHubRepos/ApsimX/Tests/Validation/Wheat/FAR/Observed' 

# Get a list of all CSV file paths in the directory
all_files = glob.glob(os.path.join(directory_path, "*.xlsx"))

# Loop through each file, read it into a DataFrame, and append to the list
for f in all_files:
    df = pd.read_excel(f)
    df.to_excel(f,index=False,sheet_name="Observed")
# Out:
# C:/GitHubRepos/ApsimX/Tests/Validation/Wheat/FAR/Observed\FAR ESW W23-02.xlsx
# C:/GitHubRepos/ApsimX/Tests/Validation/Wheat/FAR/Observed\FAR HYC W18-02-1.xlsx
# C:/GitHubRepos/ApsimX/Tests/Validation/Wheat/FAR/Observed\FAR HYC W18-02-2.xlsx
# C:/GitHubRepos/ApsimX/Tests/Validation/Wheat/FAR/Observed\FAR HYC W19-02-1.xlsx
# C:/GitHubRepos/ApsimX/Tests/Validation/Wheat/FAR/Observed\FAR SAC W18-06.xlsx
# C:/GitHubRepos/ApsimX/Tests/Validation/Wheat/FAR/Observed\FAR SAC W19-06.xlsx
# C:/GitHubRepos/ApsimX/Tests/Validation/Wheat/FAR/Observed\FAR TAS W16-06.xlsx
# C:/GitHubRepos/ApsimX/Tests/Validation/Wheat/FAR/Observed\FAR WAE W22-01.xlsx
